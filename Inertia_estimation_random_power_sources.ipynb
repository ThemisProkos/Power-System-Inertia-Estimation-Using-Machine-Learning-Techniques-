# %% [markdown]
# #Feature extraction from sequences

# %%
import h5py
import torch
import numpy as np
import pandas as pd

# === Constants ===
SAMPLE_RATE = 100.0  # 1 / 0.01s = 100Hz
DURATION = 90.0      # 90 seconds
EXPECTED_SAMPLES = int(SAMPLE_RATE * DURATION)  # Should be 9000

# === ROCOF Calculation (Updated fs) ===
def compute_max_rocof(signal: torch.Tensor, sample_rate: float = SAMPLE_RATE) -> float:
    N = len(signal)
    fft_signal = torch.fft.fft(signal)
    analytic_fft = torch.cat([
        fft_signal[0:1],
        2 * fft_signal[1:N//2],
        fft_signal[N//2:N//2+1],
        torch.zeros(N - N//2 - 1, device=signal.device)
    ])
    analytic_signal = torch.fft.ifft(analytic_fft)
    phase = torch.angle(analytic_signal)
    instantaneous_freq = torch.diff(phase) * (sample_rate / (2 * torch.pi))
    rocof = torch.diff(instantaneous_freq) * sample_rate
    return torch.max(torch.abs(rocof)).item()

# === Time of Nadir (Updated fs) ===
def find_nadir_time(signal: torch.Tensor, sample_rate: float = SAMPLE_RATE) -> float:
    nadir_idx = torch.argmin(signal).item()
    return nadir_idx / sample_rate  # Time in seconds

# === Load Data ===
with h5py.File('simulink_dataset_different_disturbances_multiple_sources_probe_signal.mat', 'r') as f:
    all_data = f['all_data'][:]        # shape: (3, 9000, N) [Verify!]
    all_targets = f['all_targets'][:]  # shape: (2, N)

# # === Verify Signal Length ===
# if all_data.shape[1] != EXPECTED_SAMPLES:
#     print(f"⚠️ Warning: Expected {EXPECTED_SAMPLES} samples, got {all_data.shape[1]}. Adjust SAMPLE_RATE or DURATION.")

# === Transpose Data ===
X = torch.tensor(np.transpose(all_data, (2, 1, 0)), dtype=torch.float32)  # (N, 9000, 3)
Y = torch.tensor(all_targets.T, dtype=torch.float32)                      # (N, 2)

# === Feature Extraction (Now uses SAMPLE_RATE) ===
def extract_features(signal, sample_rate=SAMPLE_RATE):
    return {
        'mean': signal.mean().item(),
        'std': signal.std().item(),
        'max': signal.max().item(),
        'min': signal.min().item(),
        'ptp': (signal.max() - signal.min()).item(),
        'rms': torch.sqrt(torch.mean(signal**2)).item(),
        'max_rocof': compute_max_rocof(signal, sample_rate),
        'nadir_time': find_nadir_time(signal, sample_rate)
    }

# === RMS Ratio (Unchanged) ===
def compute_rms_ratio(signal, early_pct=0.3, late_pct=0.1):
    T = signal.shape[0]
    early_len = int(T * early_pct)
    late_len = int(T * late_pct)
    early_rms = torch.sqrt(torch.mean(signal[:early_len] ** 2)).item()
    late_rms = torch.sqrt(torch.mean(signal[-late_len:] ** 2)).item()
    return late_rms / (early_rms + 1e-8)

# === Process All Samples ===
rows = []
for i in range(X.shape[0]):
    feats = {}
    for j, name in enumerate(['f1', 'f2', 'ptie']):
        sig = X[i, :, j]
        sig_feats = extract_features(sig, SAMPLE_RATE)
        for stat, val in sig_feats.items():
            feats[f"{name}_{stat}"] = val
        feats[f"{name}_rms_ratio"] = compute_rms_ratio(sig)
    feats['H1'] = Y[i, 0].item()
    feats['H2'] = Y[i, 1].item()
    rows.append(feats)

# === Save CSV ===
df = pd.DataFrame(rows)
df.to_csv("simulink_features_multiple_power_sources.csv", index=False)
print(f"✅ Saved features for {SAMPLE_RATE}Hz sampling to 'simulink_features_multiple_power_sources.csv'")
# Out:
# ✅ Saved features for 100.0Hz sampling to 'simulink_features_multiple_power_sources.csv'

# %%
import h5py
import torch
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split

# === Load the dataset ===
with h5py.File('simulink_dataset_different_disturbances_multiple_sources_probe_signal.mat', 'r') as f:
    all_data = f['all_data'][:]        # shape: (3, 6001, N)
    all_targets = f['all_targets'][:]  # shape: (2, N)

# %%
print(all_data.shape)
print(all_targets.shape)
# Out:
# (3, 9001, 1000)
# (2, 1000)

# %%
import matplotlib.pyplot as plt

def plot_sample(idx, X, Y, title_suffix=""):
    Δf1 = X[idx, :, 0].numpy()
    Δf2 = X[idx, :, 1].numpy()
    ΔPtie = X[idx, :, 2].numpy()
    H1, H2 = Y[idx, 0].item(), Y[idx, 1].item()

    plt.figure(figsize=(14, 4))
    plt.plot(Δf1, label="Δf1")
    plt.plot(Δf2, label="Δf2")
    plt.plot(ΔPtie, label="ΔPtie")
    plt.title(f"Sample #{idx} — H1: {H1:.2f}, H2: {H2:.2f} {title_suffix}")
    plt.xlabel("Time Step (0.01s)")
    plt.ylabel("Signal Value")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Convert and transpose
X_old = torch.tensor(np.transpose(all_data, (2, 1, 0)), dtype=torch.float32)  # (N, 6001, 3)
Y_old = torch.tensor(all_targets.T, dtype=torch.float32)                      # (N, 2)

print(X_old.shape)
print(Y_old.shape)
# Out:
# torch.Size([1000, 9001, 3])
# torch.Size([1000, 2])

# %%
plot_sample(idx=63, X=X_old, Y=Y_old, title_suffix=" (Raw, unnormalized)")

# %%
plot_sample(idx=990, X=X_old, Y=Y_old, title_suffix=" (Raw, unnormalized)")

# %%
plot_sample(idx=345, X=X_old, Y=Y_old, title_suffix=" (Raw, unnormalized)")

# %%
plot_sample(idx=211, X=X_old, Y=Y_old, title_suffix=" (Raw, unnormalized)")

# %% [markdown]
# New code

# %%
import pandas as pd

Statistic_Data = pd.read_csv('simulink_features_multiple_power_sources.csv')

Statistic_Data.head()
# Out:
#         f1_mean    f1_std    f1_max    f1_min    f1_ptp    f1_rms  \
# 0 -2.838670e-08  0.000077  0.000397 -0.000421  0.000818  0.000077
# 1 -5.855580e-06  0.000736  0.001917 -0.001916  0.003832  0.000736
# 2 -1.246757e-06  0.000387  0.000873 -0.000790  0.001663  0.000387
# 3 -7.898871e-06  0.000919  0.002519 -0.002583  0.005102  0.000919
# 4  9.557475e-08  0.000104  0.000469 -0.000475  0.000944  0.000104
#
#    f1_max_rocof  f1_nadir_time  f1_rms_ratio       f2_mean  ...  ptie_std  \
# 0  10808.713867          20.95      0.240889  1.260204e-07  ...  0.000929
# 1  10008.562500          89.31      6.017891  9.178045e-07  ...  0.003485
# 2  14423.495117          54.74      2.398065  1.701198e-07  ...  0.002163
# 3  10002.211914          89.30      9.447077  2.036096e-06  ...  0.004794
# 4  10003.757812          20.74      0.184425  5.053063e-09  ...  0.000934
#
#    ptie_max  ptie_min  ptie_ptp  ptie_rms  ptie_max_rocof  ptie_nadir_time  \
# 0  0.004333 -0.003946  0.008279  0.000929    10136.279297            21.55
# 1  0.008783 -0.008977  0.017760  0.003484    10035.361328            89.82
# 2  0.005833 -0.004994  0.010827  0.002163    10745.991211            23.40
# 3  0.012725 -0.013370  0.026095  0.004794    10074.004883            89.82
# 4  0.004860 -0.004661  0.009521  0.000934    10330.033203            21.32
#
#    ptie_rms_ratio        H1        H2
# 0        0.163407  7.065525  6.234028
# 1        4.721842  3.167015  7.652810
# 2        1.866641  3.455422  5.141714
# 3        7.434534  3.245635  4.656971
# 4        0.093694  4.673717  7.886208
#
# [5 rows x 29 columns]

# %%
Statistic_Data.tail()
# Out:
#           f1_mean    f1_std    f1_max    f1_min    f1_ptp    f1_rms  \
# 995 -2.699194e-08  0.000137  0.000422 -0.000570  0.000992  0.000137
# 996  2.643439e-07  0.000137  0.000567 -0.000462  0.001029  0.000137
# 997  1.000927e-08  0.000073  0.000397 -0.000394  0.000791  0.000073
# 998  2.545983e-07  0.000100  0.000395 -0.000438  0.000833  0.000100
# 999 -2.247417e-06  0.000260  0.000593 -0.000550  0.001143  0.000260
#
#      f1_max_rocof  f1_nadir_time  f1_rms_ratio       f2_mean  ...  ptie_std  \
# 995  10068.204102          20.60      0.412920 -6.676348e-08  ...  0.000953
# 996  10021.199219          20.83      1.080207 -3.656110e-07  ...  0.001464
# 997  10020.984375          20.90      0.209569  3.800775e-08  ...  0.000918
# 998  10112.792969          20.78      0.936378 -3.352260e-07  ...  0.001268
# 999  10013.154297          83.93      4.361263  2.829630e-06  ...  0.002991
#
#      ptie_max  ptie_min  ptie_ptp  ptie_rms  ptie_max_rocof  ptie_nadir_time  \
# 995  0.003233 -0.004687  0.007921  0.000952    10104.299805            21.11
# 996  0.005225 -0.003920  0.009145  0.001464    12129.943359            21.34
# 997  0.004115 -0.003990  0.008105  0.000918    13962.687500            21.56
# 998  0.003611 -0.004197  0.007808  0.001268    10013.962891            21.35
# 999  0.006482 -0.006044  0.012526  0.002991    19790.179688            82.08
#
#      ptie_rms_ratio        H1        H2
# 995        0.274346  3.619403  7.104267
# 996        0.863185  5.822209  4.378648
# 997        0.111290  7.761507  6.982743
# 998        0.865940  6.964968  4.441088
# 999        3.690492  5.893503  3.971632
#
# [5 rows x 29 columns]

# %%
Statistic_Data.columns
# Out:
# Index(['f1_mean', 'f1_std', 'f1_max', 'f1_min', 'f1_ptp', 'f1_rms',
#        'f1_max_rocof', 'f1_nadir_time', 'f1_rms_ratio', 'f2_mean', 'f2_std',
#        'f2_max', 'f2_min', 'f2_ptp', 'f2_rms', 'f2_max_rocof', 'f2_nadir_time',
#        'f2_rms_ratio', 'ptie_mean', 'ptie_std', 'ptie_max', 'ptie_min',
#        'ptie_ptp', 'ptie_rms', 'ptie_max_rocof', 'ptie_nadir_time',
#        'ptie_rms_ratio', 'H1', 'H2'],
#       dtype='object')

# %% [markdown]
# Wrong caluclation of Rocof values so we drop them

# %%
import pandas as pd
df = pd.read_csv("simulink_features_multiple_power_sources.csv")
rocof_cols = [c for c in df.columns if c.endswith("_max_rocof")]
df_clean = df.drop(columns=rocof_cols)  # προτείνεται να πετάξεις και το ptie_max_rocof αν υπάρχει
df_clean.to_csv("simulink_features_multiple_power_sources_FINAL.csv", index=False)
print("Έτοιμο: simulink_features_multiple_power_sources_FINAL.csv")
# Out:
# Έτοιμο: simulink_features_multiple_power_sources_FINAL.csv

# %%
df = df_clean.copy()

# %%
df.shape
# Out:
# (1000, 26)

# %% [markdown]
# ##PREPROCESS

# %% [markdown]
# CHECKING FOR INSTABILITY INPUT SEQUENCES

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# #df = pd.read_csv('simulink_feature_dataset_1000_outliers.csv')

# for channel in ['f1', 'f2', 'ptie']:
#     plt.figure(figsize=(8, 5))
#     plt.hist(df[f'{channel}_rms_ratio'], bins=10000)
#     plt.title(f'Distribution of RMS Ratio for {channel}')
#     plt.xlabel('RMS Late / RMS Early')
#     plt.ylabel('Frequency')
#     plt.xlim(0, 25)  # Adjust as needed
#     plt.grid(True)
#     plt.show()


import pandas as pd
import matplotlib.pyplot as plt

# Φόρτωση των δεδομένων (αποσχόλισε την ακόλουθη γραμμή αν έχεις ήδη φορτώσει τα δεδομένα)
# df = pd.read_csv('simulink_feature_dataset_1000_outliers.csv')

# Δημιουργία figure με 1 γραμμή και 3 στήλες (οριζόντια διάταξη)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))  # 18 πλάτος, 5 ύψος για να χωρέσουν και τα 3

# Λίστα με τα ονόματα των καναλιών
channels = ['f1', 'f2', 'ptie']

# Διάσχιση της λίστας των καναλιών και των αντίστοιχων αξόνων
for i, channel in enumerate(channels):
    axes[i].hist(df[f'{channel}_rms_ratio'], bins=10000)
    axes[i].set_title(f'Distribution of RMS Ratio for {channel}')
    axes[i].set_xlabel('RMS Late / RMS Early')
    axes[i].set_ylabel('Frequency')
    axes[i].set_xlim(0, 25)  # Ρύθμιση ορίων στον άξονα x
    axes[i].grid(True)

# Βελτιστοποίηση της διάταξης για να μην αλληλοκαλύπτονται τα labels
plt.tight_layout()

# Εμφάνιση όλων των plots ταυτόχρονα
plt.show()

# %%
import h5py
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load data and features
with h5py.File('simulink_dataset_different_disturbances_multiple_sources_probe_signal.mat', 'r') as f:
    all_data = f['all_data'][:]  # (3, 6001, N)

X = torch.tensor(np.transpose(all_data, (2, 1, 0)), dtype=torch.float32)  # (N, 6001, 3)
df = pd.read_csv('simulink_features_multiple_power_sources.csv')

# Select samples with high RMS ratio for any channel
threshold = 2
high_ratio_idx = df[
    (df['f1_rms_ratio'] > threshold) |
    (df['f2_rms_ratio'] > threshold) |
    (df['ptie_rms_ratio'] > threshold)
].index

print(f"Found {len(high_ratio_idx)} sequences with RMS ratio > {threshold}")

# Plot a few high-ratio sequences with H1 and H2 in the title
for idx in high_ratio_idx[:3]:  # Plot first 3
    h1_val = df.loc[idx, 'H1']
    h2_val = df.loc[idx, 'H2']

    plt.figure(figsize=(12, 5))
    for j, name in enumerate(['Δf1', 'Δf2', 'ΔPtie']):
        plt.plot(X[idx, :, j], label=name)
    plt.title(f"Sample #{idx} — H1: {h1_val:.2f}, H2: {h2_val:.2f} (RMS ratio > {threshold})")
    plt.xlabel("Time Step")
    plt.ylabel("Signal Value")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Found 278 sequences with RMS ratio > 2

# %%
import pandas as pd

#df = pd.read_csv('simulink_feature_dataset_1000_outliers.csv')

threshold = 2
unstable_counts = {
    channel: (df[f'{channel}_rms_ratio'] > threshold).sum()
    for channel in ['f1', 'f2', 'ptie']
}

total_unstable = (df[['f1_rms_ratio', 'f2_rms_ratio', 'ptie_rms_ratio']] > threshold).any(axis=1).sum()

print(f"Number of unstable sequences with RMS ratio > {threshold}:")
for ch, count in unstable_counts.items():
    print(f"  {ch}: {count}")

print(f"Total (any channel): {total_unstable}")
# Out:
# Number of unstable sequences with RMS ratio > 2:
#   f1: 266
#   f2: 251
#   ptie: 255
# Total (any channel): 278

# %%
# Assuming df is your existing DataFrame
df = df[
    (df['f1_rms_ratio'] <= 2) &
    (df['f2_rms_ratio'] <= 2) &
    (df['ptie_rms_ratio'] <= 2)
]

print(f"Filtered DataFrame shape: {df.shape}")
# Out:
# Filtered DataFrame shape: (722, 26)

# %% [markdown]
# #CORRATION MATRIX

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def filter_features_by_correlation(df, target_columns=['H1', 'H2'], threshold=0.3,
                                 verbose=True, plot_corr=True, figsize=(12, 8)):
    """
    Filter features based on their absolute correlation with target columns.

    Parameters:
    - df: pandas DataFrame containing both features and targets
    - target_columns: list of target column names (default ['H1', 'H2'])
    - threshold: minimum absolute correlation to keep a feature (default 0.2)
    - verbose: whether to print the correlation results (default True)
    - plot_corr: whether to plot the correlation heatmap (default True)
    - figsize: size of the correlation plot (default (12, 8))

    Returns:
    - DataFrame containing only selected features and targets
    - List of selected feature names
    """
    # Compute absolute correlation matrix
    corr_matrix = df.corr().abs()

    # Select only correlations of features with targets
    feature_corr = corr_matrix[target_columns].drop(index=target_columns)

    if verbose:
        print("🔍 Correlation of features with targets:\n")
        print(feature_corr)

    # Plot correlation heatmap
    if plot_corr:
        plt.figure(figsize=figsize)
        sns.heatmap(feature_corr, annot=True, cmap='coolwarm',
                   vmin=0, vmax=1, linewidths=0.5)
        plt.title(f"Absolute Correlation with Targets (Threshold = {threshold})")
        plt.show()



    # Keep features where correlation with any target is above threshold
    mask = (feature_corr > threshold).any(axis=1)
    selected_features = feature_corr[mask].index.tolist()
    unselected_features = feature_corr[~mask].index.tolist()

    if verbose:
        print(f"\n✅ Selected features (correlation > {threshold}):", selected_features)
        print(f"\n❌ Unselected features (correlation <= {threshold}):", unselected_features)


    # Return filtered dataframe and selected features

    return df[selected_features + target_columns], selected_features,unselected_features

# %%
# # With default visualization
df_filtered, selected_features ,unselected_features= filter_features_by_correlation(df)
# Out:
# 🔍 Correlation of features with targets:
#
#                        H1        H2
# f1_mean          0.001412  0.066028
# f1_std           0.651463  0.214112
# f1_max           0.635530  0.096278
# f1_min           0.711605  0.111675
# f1_ptp           0.704615  0.108632
# f1_rms           0.651460  0.214112
# f1_nadir_time    0.269362  0.207141
# f1_rms_ratio     0.366776  0.406476
# f2_mean          0.004249  0.019306
# f2_std           0.003481  0.801487
# f2_max           0.123611  0.757609
# f2_min           0.186497  0.780224
# f2_ptp           0.157333  0.784772
# f2_rms           0.003483  0.801485
# f2_nadir_time    0.130922  0.476114
# f2_rms_ratio     0.206915  0.443401
# ptie_mean        0.067720  0.163283
# ptie_std         0.363466  0.439435
# ptie_max         0.358132  0.019732
# ptie_min         0.602462  0.039593
# ptie_ptp         0.544648  0.006444
# ptie_rms         0.363464  0.439436
# ptie_nadir_time  0.128407  0.160613
# ptie_rms_ratio   0.289778  0.429306
# ✅ Selected features (correlation > 0.3): ['f1_std', 'f1_max', 'f1_min', 'f1_ptp', 'f1_rms', 'f1_rms_ratio', 'f2_std', 'f2_max', 'f2_min', 'f2_ptp', 'f2_rms', 'f2_nadir_time', 'f2_rms_ratio', 'ptie_std', 'ptie_max', 'ptie_min', 'ptie_ptp', 'ptie_rms', 'ptie_rms_ratio']
#
# ❌ Unselected features (correlation <= 0.3): ['f1_mean', 'f1_nadir_time', 'f2_mean', 'ptie_mean', 'ptie_nadir_time']

# %%
df_filtered.shape
# Out:
# (722, 21)

# %%
# import pandas as pd
# import numpy as np

# # Set random seed for reproducibility
# np.random.seed(42)

# # Create the sampled DataFrames
# df2 = df_filtered.drop(np.random.choice(df_filtered.index, size=int(len(df_filtered)*0.25), replace=False))
# df3 = df_filtered.drop(np.random.choice(df_filtered.index, size=int(len(df_filtered)*0.50), replace=False))
# df4 = df_filtered.drop(np.random.choice(df_filtered.index, size=int(len(df_filtered)*0.75), replace=False))

# # Verify the sizes
# print(f"Original size: {len(df)} rows")
# print(f"df2 (25% dropped): {len(df2)} rows (should be ~541)")
# print(f"df3 (50% dropped): {len(df3)} rows (should be ~361)")
# print(f"df4 (75% dropped): {len(df4)} rows (should be ~180)")

# %% [markdown]
# #EVALUATION

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

def evaluate_predictions(Y_true, Y_pred, names=['H1', 'H2'], verbose=True):
    """
    Evaluate predictions using various metrics and print the results.

    Parameters:
    - Y_true: numpy array of true values
    - Y_pred: numpy array of predicted values
    - names: list of names for each output variable
    - verbose: whether to print the results (default True)

    Returns:
    - Dictionary containing all evaluation metrics for each output
    """
    results = {}

    for i, name in enumerate(names):
        true = Y_true[:, i]
        pred = Y_pred[:, i]

        metrics = {
            'R2': r2_score(true, pred),
            'MAE': mean_absolute_error(true, pred),
            'RMSE': np.sqrt(mean_squared_error(true, pred)),
            'MAPE': mean_absolute_percentage_error(true, pred)*100
        }

        results[name] = metrics

        if verbose:
            print(f"{name} → R²: {metrics['R2']:.5f}, RMSE: {metrics['RMSE']:.5f}, "
                  f"MAE: {metrics['MAE']:.5f}, MAPE: {metrics['MAPE']:.2f}%")




    return results

# %% [markdown]
# #COMPARASION DATAFRAME

# %%
def create_comparison_df(Y_true, Y_pred, names=['H1', 'H2']):
    """
    Create a DataFrame comparing actual and predicted values.

    Parameters:
    - Y_true: numpy array of true values
    - Y_pred: numpy array of predicted values
    - names: list of names for each output variable

    Returns:
    - Pandas DataFrame with actual and predicted values side by side
    """
    data = {}
    for i, name in enumerate(names):
        data[f'{name}_actual'] = Y_true[:, i]
        data[f'{name}_pred'] = Y_pred[:, i]

    return pd.DataFrame(data)

# %% [markdown]
# #PLOTTER OF ESTIMATIONS

# %%
def plot_predictions(Y_true, Y_pred, target_names=['H1', 'H2'],
                    figsize=(12, 5), alpha=0.6, color='b',
                    diagonal_line=True, grid=True, tight_layout=True):
    """
    Create actual vs. predicted scatter plots for multiple targets.

    Parameters:
    - Y_true: Array of true values (2D array with shape [n_samples, n_targets])
    - Y_pred: Array of predicted values (same shape as Y_true)
    - target_names: List of names for each target variable
    - figsize: Figure size (width, height)
    - alpha: Transparency of scatter points
    - color: Color of scatter points
    - diagonal_line: Whether to plot the ideal prediction line
    - grid: Whether to show grid lines
    - tight_layout: Whether to adjust subplot spacing

    Returns:
    - matplotlib figure object
    """
    n_targets = Y_true.shape[1]
    fig, axes = plt.subplots(1, n_targets, figsize=figsize)

    if n_targets == 1:
        axes = [axes]  # Ensure axes is iterable for single target case

    for i, ax in enumerate(axes):
        true = Y_true[:, i]
        pred = Y_pred[:, i]

        # Scatter plot
        ax.scatter(true, pred, alpha=alpha, color=color)

        # Calculate R² score
        r2 = r2_score(true, pred)

        # Plot ideal prediction line
        if diagonal_line:
            min_val = min(true.min(), pred.min())
            max_val = max(true.max(), pred.max())
            ax.plot([min_val, max_val], [min_val, max_val], 'r--',
                   label='Ideal prediction')

        # Labels and title
        ax.set_xlabel(f"True {target_names[i]}")
        ax.set_ylabel(f"Predicted {target_names[i]}")
        ax.set_title(f"{target_names[i]} Prediction\n(R² = {r2:.3f})")

        if grid:
            ax.grid(True)

        if diagonal_line:
            ax.legend()

    if tight_layout:
        plt.tight_layout()

    return fig

# %% [markdown]
# #BOXPLOT

# %%
def plot_error_analysis(Y_true, Y_pred, target_names=['H1', 'H2'],
                       plot_type='boxplot', figsize=(10, 6),
                       show_stats=True, palette='Set2'):
    """
    Visualize prediction errors with multiple plot types and statistics.

    Parameters:
    - Y_true: Array of true values
    - Y_pred: Array of predicted values
    - target_names: List of target names
    - plot_type: 'boxplot', 'violin', or 'combined'
    - figsize: Figure dimensions
    - show_stats: Whether to print error statistics
    - palette: Color palette name

    Returns:
    - matplotlib figure object
    - dictionary of error statistics
    """
    # Calculate absolute errors for each target
    errors = np.abs(Y_pred - Y_true)
    stats = {}

    # Calculate error statistics
    for i, name in enumerate(target_names):
        stats[name] = {
            'mean_error': np.mean(errors[:, i]),
            'median_error': np.median(errors[:, i]),
            'max_error': np.max(errors[:, i]),
            'std_dev': np.std(errors[:, i])
        }

    if show_stats:
        print("📊 Error Statistics:")
        for name in target_names:
            print(f"\n{name}:")
            print(f"  Mean Absolute Error: {stats[name]['mean_error']:.4f}")
            print(f"  Median Absolute Error: {stats[name]['median_error']:.4f}")
            print(f"  Max Error: {stats[name]['max_error']:.4f}")
            print(f"  Standard Deviation: {stats[name]['std_dev']:.4f}")

    # Create figure
    fig, ax = plt.subplots(figsize=figsize)

    # Plot based on selected type
    if plot_type == 'boxplot':
        bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],
                       labels=[f'{name} Error' for name in target_names],
                       patch_artist=True)
        # Add colors
        colors = sns.color_palette(palette, len(target_names))
        for patch, color in zip(bp['boxes'], colors):
            patch.set_facecolor(color)

    elif plot_type == 'violin':
        vp = ax.violinplot([errors[:, i] for i in range(len(target_names))],
                         showmedians=True)
        colors = sns.color_palette(palette, len(target_names))
        for pc, color in zip(vp['bodies'], colors):
            pc.set_facecolor(color)
            pc.set_edgecolor('black')
            pc.set_alpha(0.7)
        ax.set_xticks(np.arange(1, len(target_names)+1))
        ax.set_xticklabels([f'{name} Error' for name in target_names])

    elif plot_type == 'combined':
        positions = np.arange(1, len(target_names)+1)
        # Violin plot
        vp = ax.violinplot([errors[:, i] for i in range(len(target_names))],
                         positions=positions-0.15,
                         widths=0.3,
                         showmedians=True)
        # Box plot
        bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],
                      positions=positions+0.15,
                      widths=0.2,
                      patch_artist=True)

        # Styling
        colors = sns.color_palette(palette, len(target_names))
        for pc, color in zip(vp['bodies'], colors):
            pc.set_facecolor(color)
            pc.set_edgecolor('black')
            pc.set_alpha(0.5)

        for patch, color in zip(bp['boxes'], colors):
            patch.set_facecolor(color)
            patch.set_alpha(0.7)

        ax.set_xticks(positions)
        ax.set_xticklabels([f'{name} Error' for name in target_names])

    # Common formatting
    ax.set_ylabel('Absolute Error')
    ax.set_title('Prediction Error Analysis')
    ax.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    return fig, stats

# %% [markdown]
# #CDF PLOTTER

# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Union, List, Dict, Optional

# This function plots the CDF of multiple datasets provided in a dictionary.
def plot_cdf(data_dict: dict, title: str = 'CDF Plot', xlabel: str = 'Values',
             ylabel: str = 'Cumulative Probability', figsize=(8, 6), grid=True) -> plt.Figure:
    """
    Plots the Cumulative Distribution Function (CDF) for multiple datasets.

    Parameters:
    - data_dict: Dictionary where keys are labels and values are arrays of data.
    - title: Title of the plot.
    - xlabel: Label for the x-axis.
    - ylabel: Label for the y-axis.
    - figsize: Figure size.
    - grid: Whether to show grid.

    Returns:
    - matplotlib Figure object
    """
    fig, ax = plt.subplots(figsize=figsize)

    for label, data in data_dict.items():
        # Filter out NaN/inf just in case
        data = data[np.isfinite(data)]
        if len(data) == 0:
            print(f"Warning: No finite data for label '{label}'. Skipping.")
            continue

        sorted_data = np.sort(data)
        # Calculate CDF as the empirical CDF
        cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
        ax.plot(sorted_data, cdf, label=label)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.legend()
    if grid:
        ax.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    return fig

# The plot_error_cdfs function remains the same, as it now calls the correctly
# structured plot_cdf function.
def plot_error_cdfs(Y_true: np.ndarray,
                   Y_pred: np.ndarray,
                   target_names: Optional[List[str]] = None,
                   **kwargs) -> plt.Figure:
    """
    Calculate absolute errors and plot their CDFs using the generic plot_cdf function.

    Parameters:
    - Y_true: Array of true values (shape [n_samples, n_targets])
    - Y_pred: Array of predicted values (same shape as Y_true)
    - target_names: Optional list of target names
    - **kwargs: Additional arguments for plot_cdf()

    Returns:
    - matplotlib Figure object
    """
    # Calculate absolute errors for each target
    errors = np.abs(Y_pred - Y_true)

    # Default target names
    if target_names is None:
        target_names = [f'Target {i+1}' for i in range(Y_true.shape[1])]
    elif len(target_names) != Y_true.shape[1]:
         print(f"Warning: target_names length ({len(target_names)}) does not match number of targets ({Y_true.shape[1]}). Using default names.")
         target_names = [f'Target {i+1}' for i in range(Y_true.shape[1])]


    # Create error dictionary for the generic plotter
    error_dict = {f'{name} Error': errors[:, i]
                 for i, name in enumerate(target_names)}

    # Plot using the generic CDF function
    # Pass the error_dict and any extra kwargs
    return plot_cdf(error_dict, xlabel='Absolute Error', title='CDF of Absolute Prediction Errors', **kwargs)

# Now you can use it like this (this part is unchanged):
# fig = plot_error_cdfs(Y_test, Y_pred, target_names=['H1', 'H2'])

# %% [markdown]
# #SPLITTING AND SCALING

# %%
X = df_filtered.iloc[:, :-2].values
Y = df_filtered.iloc[:, -2:].values

print(X.shape)
print(Y.shape)
# Out:
# (722, 19)
# (722, 2)

# %%
# X = df2.iloc[:, :-2].values
# Y = df2.iloc[:, -2:].values

# print(X.shape)
# print(Y.shape)

# %%
from sklearn.model_selection import train_test_split

# === Train/test split ===
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
Y_test.shape
# Out:
# (217, 2)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()


X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.transform(Y_test)

# %% [markdown]
# #ESTIMATION MODELS

# %% [markdown]
# ##RANDOM FOREST

# %%
# === Train random forest ===

from sklearn.ensemble import RandomForestRegressor


rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train_scaled, Y_train_scaled)

# === Predict and evaluate ===
Y_pred_scaled = rf.predict(X_test_scaled)


Y_pred = scaler.inverse_transform(Y_pred_scaled)
Y_true = scaler.inverse_transform(Y_test_scaled)

# %%
# Example usage:
results = evaluate_predictions(Y_true, Y_pred)
# Out:
# H1 → R²: 0.93537, RMSE: 0.32258, MAE: 0.23332, MAPE: 4.34%
# H2 → R²: 0.92647, RMSE: 0.31709, MAE: 0.23889, MAPE: 4.06%

# %%
# Example usage:
comparison_df = create_comparison_df(Y_test, Y_pred)
print(comparison_df)
# Out:
#      H1_actual   H1_pred  H2_actual   H2_pred
# 0     5.777545  6.124660   6.080493  5.948816
# 1     7.933983  7.727951   5.339190  5.442511
# 2     4.452408  4.443106   3.978493  3.991867
# 3     5.661653  5.854321   4.485403  4.498556
# 4     5.666003  6.061972   4.502955  4.546197
# ..         ...       ...        ...       ...
# 212   4.711536  4.826025   4.462227  4.480558
# 213   5.735141  6.038476   7.960858  7.810116
# 214   7.131289  7.016289   4.550109  4.725398
# 215   5.727813  5.985207   7.622150  6.862377
# 216   6.393566  6.401105   6.584186  6.785580
#
# [217 rows x 4 columns]

# %%
# Customized plot
fig = plot_predictions(Y_test, Y_pred,
                      target_names=['H1', 'H2'],
                      figsize=(14, 6),
                      alpha=0.5,
                      color='blue')

# %%
# Basic boxplot
fig, stats = plot_error_analysis(Y_test, Y_pred)
# Out:
# 📊 Error Statistics:
#
# H1:
#   Mean Absolute Error: 0.2333
#   Median Absolute Error: 0.1582
#   Max Error: 1.2861
#   Standard Deviation: 0.2228
#
# H2:
#   Mean Absolute Error: 0.2389
#   Median Absolute Error: 0.1917
#   Max Error: 1.3116
#   Standard Deviation: 0.2085
# /tmp/ipython-input-2910689032.py:47: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],

# %%
fig = plot_error_cdfs(Y_test, Y_pred, target_names=['H1', 'H2'])

# %% [markdown]
# | **Absolute Error (x)** | **Cumulative Probability (y)** | **Interpretation**                   |
# | ---------------------- | ------------------------------ | ------------------------------------ |
# | 0.05                   | 0.40                           | 40% of predictions have error ≤ 0.05 |
# | 0.10                   | 0.75                           | 75% of predictions have error ≤ 0.10 |
# | 0.20                   | 0.90                           | 90% of predictions have error ≤ 0.20 |
# | 0.40                   | 0.98                           | 98% of predictions have error ≤ 0.40 |
# | 1.00                   | 1.00                           | 100% of predictions have error ≤ 1.0 |

# %% [markdown]
# ##MAE AS A FUCTION OF NUMBER OF SAMPLES

# %%
X.shape
# Out:
# (722, 19)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Sample data - replace with your actual MAE values
# # Format: (sample_count, H1_MAE, H2_MAE)
# data = [
#     (722, 0.12970,  0.11134),   # 100% samples
#     (541, 0.11377, 0.13117),   # 75% samples
#     (361, 0.11544, 0.13808),   # 50% samples
#     (180, 0.16435, 0.17927)    # 25% samples
# ]

# # Unpack the data
# sample_counts = [x[0] for x in data]
# h1_mae = [x[1] for x in data]
# h2_mae = [x[2] for x in data]
# labels = ['100%', '75%', '50%', '25%']

# # Create the plot
# plt.figure(figsize=(10, 6))

# # Plot H1 MAE (blue line)
# plt.plot(sample_counts, h1_mae, 'b-o', linewidth=2, markersize=8, label='H1 MAE')

# # Plot H2 MAE (red line)
# plt.plot(sample_counts, h2_mae, 'r-s', linewidth=2, markersize=8, label='H2 MAE')

# # Add labels and title
# plt.xlabel('Number of Samples', fontsize=12)
# plt.ylabel('Mean Absolute Error (MAE)', fontsize=12)
# plt.title('Model Performance  vs. Dataset Size', fontsize=14)
# plt.legend(fontsize=12)

# # Add data labels
# for i, (count, h1, h2) in enumerate(data):
#     plt.text(count, h1+0.005, f"H1: {h1:.3f}", ha='center', va='bottom', fontsize=9, color='blue')
#     plt.text(count, h2+0.005, f"H2: {h2:.3f}", ha='center', va='top', fontsize=9, color='red')
#     plt.text(count, min(h1,h2)-0.03, labels[i], ha='center', va='top', fontsize=10)

# # Adjust plot limits
# buffer = max(max(h1_mae), max(h2_mae)) * 0.1
# plt.xlim(min(sample_counts)-50, max(sample_counts)+50)
# plt.ylim(min(min(h1_mae), min(h2_mae))-buffer, max(max(h1_mae), max(h2_mae))+buffer)

# # Add grid
# plt.grid(True, alpha=0.3)

# # Show plot
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ##LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression



# Train Linear Regression
model = LinearRegression()
model.fit(X_train_scaled, Y_train)

# Predictions
Y_pred = model.predict(X_test_scaled)
Y_true = Y_test.copy()


results = evaluate_predictions(Y_true, Y_pred)

print("-------------------------------------------")
comparison_df = create_comparison_df(Y_test, Y_pred)
print(comparison_df)

print("-------------------------------------------")

# Customized plot
fig = plot_predictions(Y_test, Y_pred,
                      target_names=['H1', 'H2'],
                      figsize=(14, 6),
                      alpha=0.5,
                      color='green')

# Basic boxplot
fig, stats = plot_error_analysis(Y_test, Y_pred)

fig = plot_error_cdfs(Y_test, Y_pred, target_names=['H1', 'H2'])
# Out:
# H1 → R²: 0.82549, RMSE: 0.53008, MAE: 0.39391, MAPE: 7.57%
# H2 → R²: 0.86626, RMSE: 0.42765, MAE: 0.32525, MAPE: 5.84%
# -------------------------------------------
#      H1_actual   H1_pred  H2_actual   H2_pred
# 0     5.777545  5.838635   6.080493  6.251598
# 1     7.933983  7.445731   5.339190  5.403215
# 2     4.452408  3.761371   3.978493  3.804754
# 3     5.661653  6.030409   4.485403  4.570925
# 4     5.666003  5.992403   4.502955  4.535294
# ..         ...       ...        ...       ...
# 212   4.711536  3.880945   4.462227  5.282982
# 213   5.735141  5.822811   7.960858  7.541155
# 214   7.131289  6.955009   4.550109  4.297374
# 215   5.727813  5.591042   7.622150  7.001163
# 216   6.393566  6.235014   6.584186  6.895916
#
# [217 rows x 4 columns]
# -------------------------------------------
# 📊 Error Statistics:
#
# H1:
#   Mean Absolute Error: 0.3939
#   Median Absolute Error: 0.3260
#   Max Error: 2.8654
#   Standard Deviation: 0.3547
#
# H2:
#   Mean Absolute Error: 0.3252
#   Median Absolute Error: 0.2412
#   Max Error: 1.4895
#   Standard Deviation: 0.2777
# /tmp/ipython-input-2910689032.py:47: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],

# %%
X.shape
# Out:
# (722, 19)

# %% [markdown]
# ##XGBOOST

# %%
import xgboost as xgb

# === Separate features and targets ===
X = df_filtered.drop(columns=['H1', 'H2']).values
Y = df_filtered[['H1', 'H2']].values

# === Train/val/test split ===
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# === Min-Max Scaling ===
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()

X_train_scaled = X_scaler.fit_transform(X_train)
X_val_scaled   = X_scaler.transform(X_val)
X_test_scaled  = X_scaler.transform(X_test)

Y_train_scaled = Y_scaler.fit_transform(Y_train)
Y_val_scaled   = Y_scaler.transform(Y_val)
Y_test_scaled  = Y_scaler.transform(Y_test)

# === Train a separate XGBoost model for H1 and H2 ===
models = []
for i in range(Y.shape[1]):
    model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)
    model.fit(X_train_scaled, Y_train_scaled[:, i])
    models.append(model)

# === Predict and inverse transform ===
Y_pred_scaled = np.column_stack([model.predict(X_test_scaled) for model in models])
Y_pred = Y_scaler.inverse_transform(Y_pred_scaled)
Y_true = Y_scaler.inverse_transform(Y_test_scaled)

# %%
results = evaluate_predictions(Y_true, Y_pred)

print("-------------------------------------------")
comparison_df = create_comparison_df(Y_test, Y_pred)
print(comparison_df)

print("-------------------------------------------")

# Customized plot
fig = plot_predictions(Y_test, Y_pred,
                      target_names=['H1', 'H2'],
                      figsize=(14, 6),
                      alpha=0.5,
                      color='purple')

# Basic boxplot
fig, stats = plot_error_analysis(Y_test, Y_pred)

fig = plot_error_cdfs(Y_test, Y_pred, target_names=['H1', 'H2'])
# Out:
# H1 → R²: 0.94772, RMSE: 0.30286, MAE: 0.22047, MAPE: 4.09%
# H2 → R²: 0.91648, RMSE: 0.34033, MAE: 0.25008, MAPE: 4.21%
# -------------------------------------------
#      H1_actual   H1_pred  H2_actual   H2_pred
# 0     6.135692  5.947376   7.950549  7.761911
# 1     7.131289  7.231277   4.550109  4.411254
# 2     7.485193  7.701948   6.880697  6.851233
# 3     5.650443  5.360809   5.329834  5.134027
# 4     4.355889  3.257108   4.052103  4.552887
# ..         ...       ...        ...       ...
# 104   3.848963  3.749502   7.703586  6.517705
# 105   5.669783  5.351016   6.070156  6.229961
# 106   5.143757  5.233249   7.902701  7.534492
# 107   6.619014  6.205326   4.389610  4.610847
# 108   7.160204  7.257654   5.980690  5.806263
#
# [109 rows x 4 columns]
# -------------------------------------------
# 📊 Error Statistics:
#
# H1:
#   Mean Absolute Error: 0.2205
#   Median Absolute Error: 0.1723
#   Max Error: 1.0988
#   Standard Deviation: 0.2076
#
# H2:
#   Mean Absolute Error: 0.2501
#   Median Absolute Error: 0.1617
#   Max Error: 1.1859
#   Standard Deviation: 0.2308
# /tmp/ipython-input-2910689032.py:47: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],

# %% [markdown]
# ##SVR

# %%
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler # Import MinMaxScaler
import numpy as np # Import numpy

# Assuming X and Y are loaded from the .mat file as done earlier in the notebook

# === Train/test split ===
# This split determines the samples for the SVR model
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Scale Y data as well if needed for the model
Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.transform(Y_test) # Use the Y_test from THIS split

# -------------------------------
# Train Multi-Output SVR
# -------------------------------
base_svr = SVR(kernel='rbf', C=100, epsilon=0.1)
model_svr = MultiOutputRegressor(base_svr)

model_svr.fit(X_train_scaled, Y_train_scaled) # Train on scaled Y

# -------------------------------
# Predict and Inverse-Transform y
# -------------------------------
y_pred_scaled = model_svr.predict(X_test_scaled)
Y_pred = scaler.inverse_transform(y_pred_scaled)

# Use the correct Y_test from THIS split as the true values for evaluation
Y_true = Y_test # Now Y_true and Y_pred will have the same number of samples (219)

# -------------------------------
# Evaluate and Plot (assuming helper functions are defined elsewhere)
# -------------------------------
results = evaluate_predictions(Y_true, Y_pred) # Y_true and Y_pred have 219 samples

print("-------------------------------------------")
comparison_df = create_comparison_df(Y_true, Y_pred) # Use Y_true for consistency
print(comparison_df)

print("-------------------------------------------")

# Customized plot
fig = plot_predictions(Y_true, Y_pred, # Use Y_true
                      target_names=['H1', 'H2'],
                      figsize=(14, 6),
                      alpha=0.5,
                      color='blue')

# Basic boxplot
fig, stats = plot_error_analysis(Y_true, Y_pred) # Use Y_true

# Ensure Y_test is also a numpy array for plot_error_cdfs
fig = plot_error_cdfs(Y_true, Y_pred, target_names=['H1', 'H2']) # Use Y_true
# Out:
# H1 → R²: 0.92548, RMSE: 0.34640, MAE: 0.27811, MAPE: 5.33%
# H2 → R²: 0.90838, RMSE: 0.35395, MAE: 0.24953, MAPE: 4.42%
# -------------------------------------------
#      H1_actual   H1_pred  H2_actual   H2_pred
# 0     5.777545  6.168445   6.080493  6.050768
# 1     7.933983  7.616146   5.339190  5.360985
# 2     4.452408  4.605886   3.978493  4.191120
# 3     5.661653  5.794885   4.485403  4.351778
# 4     5.666003  5.589700   4.502955  4.713059
# ..         ...       ...        ...       ...
# 212   4.711536  4.275526   4.462227  4.664113
# 213   5.735141  6.083992   7.960858  7.816052
# 214   7.131289  7.006245   4.550109  4.699786
# 215   5.727813  6.077329   7.622150  7.041096
# 216   6.393566  6.619768   6.584186  6.844712
#
# [217 rows x 4 columns]
# -------------------------------------------
# 📊 Error Statistics:
#
# H1:
#   Mean Absolute Error: 0.2781
#   Median Absolute Error: 0.2293
#   Max Error: 1.2993
#   Standard Deviation: 0.2065
#
# H2:
#   Mean Absolute Error: 0.2495
#   Median Absolute Error: 0.1711
#   Max Error: 1.6717
#   Standard Deviation: 0.2510
# /tmp/ipython-input-2910689032.py:47: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],

# %% [markdown]
# ##MLP with 2 layers

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X.shape
# Out:
# (722, 19)

# %%
print("X dimensions: ",X.shape)
print("Y dimensions: ",Y.shape)
# Out:
# X dimensions:  (722, 19)
# Y dimensions:  (722, 2)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class InertiaRegressionDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_dataset = InertiaRegressionDataset(X_train_scaled, Y_train_scaled)
test_dataset = InertiaRegressionDataset(X_test_scaled, Y_test_scaled)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
import torch.nn as nn

class RegressionModel(nn.Module):
    def __init__(self, input_dim):
        super(RegressionModel, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64
            ),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 2)  # 2 outputs: H1 and H2
        )

    def forward(self, x):
        return self.net(x)

model = RegressionModel(input_dim=19)

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = model.to(device)

# criterion = nn.MSELoss()

# # Hyperparameters
# learning_rate = 1e-3
# weight_decay = 1e-5
# early_stop_patience = 5      # number of checks without improvement
# check_every = 30             # check every 30 batches
# best_val_loss = float('inf')
# no_improve_count = 0
# step = 0

# optimizer = torch.optim.Adam(
#     model.parameters(),
#     lr=learning_rate,
#     weight_decay=weight_decay
# )

# for epoch in range(2000):
#     model.train()
#     running_loss = 0
#     for batch_x, batch_y in train_loader:
#         step += 1
#         batch_x, batch_y = batch_x.to(device), batch_y.to(device)
#         optimizer.zero_grad()
#         output = model(batch_x)
#         loss = criterion(output, batch_y)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()

#         # ✅ Check validation loss every `check_every` steps
#         if step % check_every == 0:
#             model.eval()
#             val_losses = []
#             with torch.no_grad():
#                 for val_x, val_y in test_loader:  # Use test_loader as validation
#                     val_x, val_y = val_x.to(device), val_y.to(device)
#                     val_out = model(val_x)
#                     val_loss = criterion(val_out, val_y).item()
#                     val_losses.append(val_loss)

#             avg_val_loss = sum(val_losses) / len(val_losses)
#             print(f"Step {step}, Validation Loss: {avg_val_loss:.4f}")

#             if avg_val_loss < best_val_loss:
#                 best_val_loss = avg_val_loss
#                 no_improve_count = 0
#             else:
#                 no_improve_count += 1
#                 if no_improve_count >= early_stop_patience:
#                     print(f"Early stopping triggered at step {step}.")
#                     break
#             model.train()

#     print(f"Epoch {epoch+1}, Training Loss: {running_loss / len(train_loader):.4f}")

#     if no_improve_count >= early_stop_patience:
#         print(f"Early stopping ended training at epoch {epoch+1}.")
#         break

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)




for epoch in range(1500):
    model.train()
    running_loss = 0
    for batch_x, batch_y in train_loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        optimizer.zero_grad()
        output = model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {running_loss / len(train_loader):.4f}")
# Out:
# Epoch 1, Loss: 0.2798
# Epoch 2, Loss: 0.1406
# Epoch 3, Loss: 0.0853
# Epoch 4, Loss: 0.0601
# Epoch 5, Loss: 0.0416
# Epoch 6, Loss: 0.0323
# Epoch 7, Loss: 0.0262
# Epoch 8, Loss: 0.0219
# Epoch 9, Loss: 0.0186
# Epoch 10, Loss: 0.0159
# Epoch 11, Loss: 0.0139
# Epoch 12, Loss: 0.0125
# Epoch 13, Loss: 0.0115
# Epoch 14, Loss: 0.0105
# Epoch 15, Loss: 0.0100
# Epoch 16, Loss: 0.0095
# Epoch 17, Loss: 0.0090
# Epoch 18, Loss: 0.0087
# Epoch 19, Loss: 0.0085
# Epoch 20, Loss: 0.0081
# Epoch 21, Loss: 0.0079
# Epoch 22, Loss: 0.0077
# Epoch 23, Loss: 0.0076
# Epoch 24, Loss: 0.0072
# Epoch 25, Loss: 0.0070
# Epoch 26, Loss: 0.0068
# Epoch 27, Loss: 0.0065
# Epoch 28, Loss: 0.0063
# Epoch 29, Loss: 0.0063
# Epoch 30, Loss: 0.0060
# Epoch 31, Loss: 0.0061
# Epoch 32, Loss: 0.0058
# Epoch 33, Loss: 0.0057
# Epoch 34, Loss: 0.0057
# Epoch 35, Loss: 0.0054
# Epoch 36, Loss: 0.0054
# Epoch 37, Loss: 0.0054
# Epoch 38, Loss: 0.0052
# Epoch 39, Loss: 0.0049
# Epoch 40, Loss: 0.0047
# Epoch 41, Loss: 0.0048
# Epoch 42, Loss: 0.0046
# Epoch 43, Loss: 0.0045
# Epoch 44, Loss: 0.0043
# Epoch 45, Loss: 0.0044
# Epoch 46, Loss: 0.0044
# Epoch 47, Loss: 0.0041
# Epoch 48, Loss: 0.0041
# Epoch 49, Loss: 0.0042
# Epoch 50, Loss: 0.0040
# Epoch 51, Loss: 0.0039
# Epoch 52, Loss: 0.0041
# Epoch 53, Loss: 0.0042
# Epoch 54, Loss: 0.0040
# Epoch 55, Loss: 0.0037
# Epoch 56, Loss: 0.0037
# Epoch 57, Loss: 0.0038
# Epoch 58, Loss: 0.0040
# Epoch 59, Loss: 0.0036
# Epoch 60, Loss: 0.0039
# Epoch 61, Loss: 0.0034
# Epoch 62, Loss: 0.0034
# Epoch 63, Loss: 0.0033
# Epoch 64, Loss: 0.0033
# Epoch 65, Loss: 0.0033
# Epoch 66, Loss: 0.0032
# Epoch 67, Loss: 0.0032
# Epoch 68, Loss: 0.0031
# Epoch 69, Loss: 0.0030
# Epoch 70, Loss: 0.0030
# Epoch 71, Loss: 0.0029
# Epoch 72, Loss: 0.0028
# Epoch 73, Loss: 0.0028
# Epoch 74, Loss: 0.0028
# Epoch 75, Loss: 0.0027
# Epoch 76, Loss: 0.0027
# Epoch 77, Loss: 0.0028
# Epoch 78, Loss: 0.0028
# Epoch 79, Loss: 0.0027
# Epoch 80, Loss: 0.0026
# Epoch 81, Loss: 0.0026
# Epoch 82, Loss: 0.0027
# Epoch 83, Loss: 0.0025
# Epoch 84, Loss: 0.0025
# Epoch 85, Loss: 0.0024
# Epoch 86, Loss: 0.0025
# Epoch 87, Loss: 0.0025
# Epoch 88, Loss: 0.0024
# Epoch 89, Loss: 0.0025
# Epoch 90, Loss: 0.0023
# Epoch 91, Loss: 0.0025
# Epoch 92, Loss: 0.0028
# Epoch 93, Loss: 0.0023
# Epoch 94, Loss: 0.0023
# Epoch 95, Loss: 0.0023
# Epoch 96, Loss: 0.0022
# Epoch 97, Loss: 0.0022
# Epoch 98, Loss: 0.0022
# Epoch 99, Loss: 0.0023
# Epoch 100, Loss: 0.0022
# Epoch 101, Loss: 0.0023
# Epoch 102, Loss: 0.0022
# Epoch 103, Loss: 0.0026
# Epoch 104, Loss: 0.0024
# Epoch 105, Loss: 0.0022
# Epoch 106, Loss: 0.0021
# Epoch 107, Loss: 0.0022
# Epoch 108, Loss: 0.0022
# Epoch 109, Loss: 0.0022
# Epoch 110, Loss: 0.0021
# Epoch 111, Loss: 0.0020
# Epoch 112, Loss: 0.0020
# Epoch 113, Loss: 0.0020
# Epoch 114, Loss: 0.0021
# Epoch 115, Loss: 0.0020
# Epoch 116, Loss: 0.0021
# Epoch 117, Loss: 0.0021
# Epoch 118, Loss: 0.0023
# Epoch 119, Loss: 0.0021
# Epoch 120, Loss: 0.0020
# Epoch 121, Loss: 0.0019
# Epoch 122, Loss: 0.0020
# Epoch 123, Loss: 0.0020
# Epoch 124, Loss: 0.0020
# Epoch 125, Loss: 0.0021
# Epoch 126, Loss: 0.0020
# Epoch 127, Loss: 0.0019
# Epoch 128, Loss: 0.0019
# Epoch 129, Loss: 0.0019
# Epoch 130, Loss: 0.0018
# Epoch 131, Loss: 0.0020
# Epoch 132, Loss: 0.0019
# Epoch 133, Loss: 0.0019
# Epoch 134, Loss: 0.0018
# Epoch 135, Loss: 0.0019
# Epoch 136, Loss: 0.0018
# Epoch 137, Loss: 0.0018
# Epoch 138, Loss: 0.0019
# Epoch 139, Loss: 0.0019
# Epoch 140, Loss: 0.0021
# Epoch 141, Loss: 0.0020
# Epoch 142, Loss: 0.0021
# Epoch 143, Loss: 0.0018
# Epoch 144, Loss: 0.0018
# Epoch 145, Loss: 0.0019
# Epoch 146, Loss: 0.0018
# Epoch 147, Loss: 0.0018
# Epoch 148, Loss: 0.0018
# Epoch 149, Loss: 0.0018
# Epoch 150, Loss: 0.0018
# Epoch 151, Loss: 0.0017
# Epoch 152, Loss: 0.0018
# Epoch 153, Loss: 0.0018
# Epoch 154, Loss: 0.0018
# Epoch 155, Loss: 0.0018
# Epoch 156, Loss: 0.0018
# Epoch 157, Loss: 0.0017
# Epoch 158, Loss: 0.0018
# Epoch 159, Loss: 0.0018
# Epoch 160, Loss: 0.0019
# Epoch 161, Loss: 0.0018
# Epoch 162, Loss: 0.0017
# Epoch 163, Loss: 0.0019
# Epoch 164, Loss: 0.0018
# Epoch 165, Loss: 0.0019
# Epoch 166, Loss: 0.0018
# Epoch 167, Loss: 0.0017
# Epoch 168, Loss: 0.0017
# Epoch 169, Loss: 0.0018
# Epoch 170, Loss: 0.0018
# Epoch 171, Loss: 0.0017
# Epoch 172, Loss: 0.0018
# Epoch 173, Loss: 0.0017
# Epoch 174, Loss: 0.0018
# Epoch 175, Loss: 0.0017
# Epoch 176, Loss: 0.0017
# Epoch 177, Loss: 0.0016
# Epoch 178, Loss: 0.0017
# Epoch 179, Loss: 0.0016
# Epoch 180, Loss: 0.0016
# Epoch 181, Loss: 0.0016
# Epoch 182, Loss: 0.0017
# Epoch 183, Loss: 0.0017
# Epoch 184, Loss: 0.0018
# Epoch 185, Loss: 0.0016
# Epoch 186, Loss: 0.0016
# Epoch 187, Loss: 0.0017
# Epoch 188, Loss: 0.0017
# Epoch 189, Loss: 0.0016
# Epoch 190, Loss: 0.0016
# Epoch 191, Loss: 0.0016
# Epoch 192, Loss: 0.0016
# Epoch 193, Loss: 0.0017
# Epoch 194, Loss: 0.0020
# Epoch 195, Loss: 0.0017
# Epoch 196, Loss: 0.0017
# Epoch 197, Loss: 0.0016
# Epoch 198, Loss: 0.0016
# Epoch 199, Loss: 0.0016
# Epoch 200, Loss: 0.0017
# Epoch 201, Loss: 0.0020
# Epoch 202, Loss: 0.0018
# Epoch 203, Loss: 0.0016
# Epoch 204, Loss: 0.0016
# Epoch 205, Loss: 0.0016
# Epoch 206, Loss: 0.0016
# Epoch 207, Loss: 0.0017
# Epoch 208, Loss: 0.0016
# Epoch 209, Loss: 0.0018
# Epoch 210, Loss: 0.0016
# Epoch 211, Loss: 0.0017
# Epoch 212, Loss: 0.0016
# Epoch 213, Loss: 0.0015
# Epoch 214, Loss: 0.0016
# Epoch 215, Loss: 0.0016
# Epoch 216, Loss: 0.0017
# Epoch 217, Loss: 0.0017
# Epoch 218, Loss: 0.0017
# Epoch 219, Loss: 0.0019
# Epoch 220, Loss: 0.0016
# Epoch 221, Loss: 0.0018
# Epoch 222, Loss: 0.0017
# Epoch 223, Loss: 0.0016
# Epoch 224, Loss: 0.0017
# Epoch 225, Loss: 0.0015
# Epoch 226, Loss: 0.0016
# Epoch 227, Loss: 0.0015
# Epoch 228, Loss: 0.0016
# Epoch 229, Loss: 0.0017
# Epoch 230, Loss: 0.0016
# Epoch 231, Loss: 0.0015
# Epoch 232, Loss: 0.0015
# Epoch 233, Loss: 0.0016
# Epoch 234, Loss: 0.0016
# Epoch 235, Loss: 0.0016
# Epoch 236, Loss: 0.0015
# Epoch 237, Loss: 0.0016
# Epoch 238, Loss: 0.0016
# Epoch 239, Loss: 0.0016
# Epoch 240, Loss: 0.0015
# Epoch 241, Loss: 0.0015
# Epoch 242, Loss: 0.0016
# Epoch 243, Loss: 0.0016
# Epoch 244, Loss: 0.0015
# Epoch 245, Loss: 0.0016
# Epoch 246, Loss: 0.0015
# Epoch 247, Loss: 0.0015
# Epoch 248, Loss: 0.0015
# Epoch 249, Loss: 0.0015
# Epoch 250, Loss: 0.0016
# Epoch 251, Loss: 0.0016
# Epoch 252, Loss: 0.0016
# Epoch 253, Loss: 0.0015
# Epoch 254, Loss: 0.0014
# Epoch 255, Loss: 0.0014
# Epoch 256, Loss: 0.0015
# Epoch 257, Loss: 0.0015
# Epoch 258, Loss: 0.0015
# Epoch 259, Loss: 0.0015
# Epoch 260, Loss: 0.0014
# Epoch 261, Loss: 0.0015
# Epoch 262, Loss: 0.0014
# Epoch 263, Loss: 0.0014
# Epoch 264, Loss: 0.0014
# Epoch 265, Loss: 0.0015
# Epoch 266, Loss: 0.0015
# Epoch 267, Loss: 0.0015
# Epoch 268, Loss: 0.0015
# Epoch 269, Loss: 0.0014
# Epoch 270, Loss: 0.0015
# Epoch 271, Loss: 0.0016
# Epoch 272, Loss: 0.0015
# Epoch 273, Loss: 0.0017
# Epoch 274, Loss: 0.0016
# Epoch 275, Loss: 0.0017
# Epoch 276, Loss: 0.0016
# Epoch 277, Loss: 0.0014
# Epoch 278, Loss: 0.0014
# Epoch 279, Loss: 0.0016
# Epoch 280, Loss: 0.0016
# Epoch 281, Loss: 0.0016
# Epoch 282, Loss: 0.0016
# Epoch 283, Loss: 0.0015
# Epoch 284, Loss: 0.0015
# Epoch 285, Loss: 0.0014
# Epoch 286, Loss: 0.0014
# Epoch 287, Loss: 0.0014
# Epoch 288, Loss: 0.0015
# Epoch 289, Loss: 0.0015
# Epoch 290, Loss: 0.0015
# Epoch 291, Loss: 0.0015
# Epoch 292, Loss: 0.0014
# Epoch 293, Loss: 0.0015
# Epoch 294, Loss: 0.0015
# Epoch 295, Loss: 0.0014
# Epoch 296, Loss: 0.0014
# Epoch 297, Loss: 0.0014
# Epoch 298, Loss: 0.0015
# Epoch 299, Loss: 0.0015
# Epoch 300, Loss: 0.0015
# Epoch 301, Loss: 0.0015
# Epoch 302, Loss: 0.0014
# Epoch 303, Loss: 0.0015
# Epoch 304, Loss: 0.0014
# Epoch 305, Loss: 0.0014
# Epoch 306, Loss: 0.0015
# Epoch 307, Loss: 0.0014
# Epoch 308, Loss: 0.0014
# Epoch 309, Loss: 0.0014
# Epoch 310, Loss: 0.0015
# Epoch 311, Loss: 0.0015
# Epoch 312, Loss: 0.0015
# Epoch 313, Loss: 0.0015
# Epoch 314, Loss: 0.0014
# Epoch 315, Loss: 0.0014
# Epoch 316, Loss: 0.0016
# Epoch 317, Loss: 0.0014
# Epoch 318, Loss: 0.0014
# Epoch 319, Loss: 0.0014
# Epoch 320, Loss: 0.0014
# Epoch 321, Loss: 0.0014
# Epoch 322, Loss: 0.0014
# Epoch 323, Loss: 0.0014
# Epoch 324, Loss: 0.0014
# Epoch 325, Loss: 0.0015
# Epoch 326, Loss: 0.0014
# Epoch 327, Loss: 0.0014
# Epoch 328, Loss: 0.0013
# Epoch 329, Loss: 0.0015
# Epoch 330, Loss: 0.0013
# Epoch 331, Loss: 0.0014
# Epoch 332, Loss: 0.0015
# Epoch 333, Loss: 0.0013
# Epoch 334, Loss: 0.0014
# Epoch 335, Loss: 0.0014
# Epoch 336, Loss: 0.0016
# Epoch 337, Loss: 0.0015
# Epoch 338, Loss: 0.0013
# Epoch 339, Loss: 0.0014
# Epoch 340, Loss: 0.0013
# Epoch 341, Loss: 0.0014
# Epoch 342, Loss: 0.0014
# Epoch 343, Loss: 0.0014
# Epoch 344, Loss: 0.0014
# Epoch 345, Loss: 0.0013
# Epoch 346, Loss: 0.0014
# Epoch 347, Loss: 0.0015
# Epoch 348, Loss: 0.0015
# Epoch 349, Loss: 0.0015
# Epoch 350, Loss: 0.0014
# Epoch 351, Loss: 0.0016
# Epoch 352, Loss: 0.0015
# Epoch 353, Loss: 0.0013
# Epoch 354, Loss: 0.0015
# Epoch 355, Loss: 0.0014
# Epoch 356, Loss: 0.0014
# Epoch 357, Loss: 0.0016
# Epoch 358, Loss: 0.0014
# Epoch 359, Loss: 0.0014
# Epoch 360, Loss: 0.0014
# Epoch 361, Loss: 0.0015
# Epoch 362, Loss: 0.0013
# Epoch 363, Loss: 0.0013
# Epoch 364, Loss: 0.0013
# Epoch 365, Loss: 0.0013
# Epoch 366, Loss: 0.0013
# Epoch 367, Loss: 0.0013
# Epoch 368, Loss: 0.0014
# Epoch 369, Loss: 0.0015
# Epoch 370, Loss: 0.0013
# Epoch 371, Loss: 0.0013
# Epoch 372, Loss: 0.0015
# Epoch 373, Loss: 0.0015
# Epoch 374, Loss: 0.0015
# Epoch 375, Loss: 0.0015
# Epoch 376, Loss: 0.0016
# Epoch 377, Loss: 0.0014
# Epoch 378, Loss: 0.0014
# Epoch 379, Loss: 0.0012
# Epoch 380, Loss: 0.0013
# Epoch 381, Loss: 0.0013
# Epoch 382, Loss: 0.0013
# Epoch 383, Loss: 0.0013
# Epoch 384, Loss: 0.0013
# Epoch 385, Loss: 0.0013
# Epoch 386, Loss: 0.0013
# Epoch 387, Loss: 0.0015
# Epoch 388, Loss: 0.0016
# Epoch 389, Loss: 0.0014
# Epoch 390, Loss: 0.0013
# Epoch 391, Loss: 0.0012
# Epoch 392, Loss: 0.0013
# Epoch 393, Loss: 0.0013
# Epoch 394, Loss: 0.0014
# Epoch 395, Loss: 0.0014
# Epoch 396, Loss: 0.0013
# Epoch 397, Loss: 0.0014
# Epoch 398, Loss: 0.0012
# Epoch 399, Loss: 0.0014
# Epoch 400, Loss: 0.0013
# Epoch 401, Loss: 0.0013
# Epoch 402, Loss: 0.0016
# Epoch 403, Loss: 0.0016
# Epoch 404, Loss: 0.0014
# Epoch 405, Loss: 0.0012
# Epoch 406, Loss: 0.0013
# Epoch 407, Loss: 0.0013
# Epoch 408, Loss: 0.0013
# Epoch 409, Loss: 0.0012
# Epoch 410, Loss: 0.0013
# Epoch 411, Loss: 0.0013
# Epoch 412, Loss: 0.0012
# Epoch 413, Loss: 0.0013
# Epoch 414, Loss: 0.0013
# Epoch 415, Loss: 0.0013
# Epoch 416, Loss: 0.0012
# Epoch 417, Loss: 0.0013
# Epoch 418, Loss: 0.0013
# Epoch 419, Loss: 0.0012
# Epoch 420, Loss: 0.0013
# Epoch 421, Loss: 0.0013
# Epoch 422, Loss: 0.0012
# Epoch 423, Loss: 0.0013
# Epoch 424, Loss: 0.0012
# Epoch 425, Loss: 0.0012
# Epoch 426, Loss: 0.0012
# Epoch 427, Loss: 0.0013
# Epoch 428, Loss: 0.0014
# Epoch 429, Loss: 0.0013
# Epoch 430, Loss: 0.0013
# Epoch 431, Loss: 0.0013
# Epoch 432, Loss: 0.0016
# Epoch 433, Loss: 0.0014
# Epoch 434, Loss: 0.0014
# Epoch 435, Loss: 0.0014
# Epoch 436, Loss: 0.0013
# Epoch 437, Loss: 0.0012
# Epoch 438, Loss: 0.0013
# Epoch 439, Loss: 0.0013
# Epoch 440, Loss: 0.0013
# Epoch 441, Loss: 0.0014
# Epoch 442, Loss: 0.0012
# Epoch 443, Loss: 0.0012
# Epoch 444, Loss: 0.0013
# Epoch 445, Loss: 0.0013
# Epoch 446, Loss: 0.0012
# Epoch 447, Loss: 0.0012
# Epoch 448, Loss: 0.0013
# Epoch 449, Loss: 0.0012
# Epoch 450, Loss: 0.0012
# Epoch 451, Loss: 0.0012
# Epoch 452, Loss: 0.0012
# Epoch 453, Loss: 0.0012
# Epoch 454, Loss: 0.0013
# Epoch 455, Loss: 0.0013
# Epoch 456, Loss: 0.0013
# Epoch 457, Loss: 0.0012
# Epoch 458, Loss: 0.0012
# Epoch 459, Loss: 0.0012
# Epoch 460, Loss: 0.0012
# Epoch 461, Loss: 0.0012
# Epoch 462, Loss: 0.0012
# Epoch 463, Loss: 0.0014
# Epoch 464, Loss: 0.0012
# Epoch 465, Loss: 0.0011
# Epoch 466, Loss: 0.0012
# Epoch 467, Loss: 0.0012
# Epoch 468, Loss: 0.0013
# Epoch 469, Loss: 0.0013
# Epoch 470, Loss: 0.0012
# Epoch 471, Loss: 0.0012
# Epoch 472, Loss: 0.0014
# Epoch 473, Loss: 0.0012
# Epoch 474, Loss: 0.0012
# Epoch 475, Loss: 0.0012
# Epoch 476, Loss: 0.0012
# Epoch 477, Loss: 0.0012
# Epoch 478, Loss: 0.0012
# Epoch 479, Loss: 0.0012
# Epoch 480, Loss: 0.0012
# Epoch 481, Loss: 0.0013
# Epoch 482, Loss: 0.0012
# Epoch 483, Loss: 0.0013
# Epoch 484, Loss: 0.0014
# Epoch 485, Loss: 0.0014
# Epoch 486, Loss: 0.0012
# Epoch 487, Loss: 0.0012
# Epoch 488, Loss: 0.0012
# Epoch 489, Loss: 0.0013
# Epoch 490, Loss: 0.0012
# Epoch 491, Loss: 0.0012
# Epoch 492, Loss: 0.0012
# Epoch 493, Loss: 0.0012
# Epoch 494, Loss: 0.0012
# Epoch 495, Loss: 0.0012
# Epoch 496, Loss: 0.0012
# Epoch 497, Loss: 0.0012
# Epoch 498, Loss: 0.0012
# Epoch 499, Loss: 0.0012
# Epoch 500, Loss: 0.0011
# Epoch 501, Loss: 0.0012
# Epoch 502, Loss: 0.0011
# Epoch 503, Loss: 0.0013
# Epoch 504, Loss: 0.0013
# Epoch 505, Loss: 0.0011
# Epoch 506, Loss: 0.0012
# Epoch 507, Loss: 0.0012
# Epoch 508, Loss: 0.0013
# Epoch 509, Loss: 0.0012
# Epoch 510, Loss: 0.0012
# Epoch 511, Loss: 0.0012
# Epoch 512, Loss: 0.0012
# Epoch 513, Loss: 0.0013
# Epoch 514, Loss: 0.0013
# Epoch 515, Loss: 0.0012
# Epoch 516, Loss: 0.0013
# Epoch 517, Loss: 0.0015
# Epoch 518, Loss: 0.0014
# Epoch 519, Loss: 0.0012
# Epoch 520, Loss: 0.0012
# Epoch 521, Loss: 0.0012
# Epoch 522, Loss: 0.0011
# Epoch 523, Loss: 0.0012
# Epoch 524, Loss: 0.0012
# Epoch 525, Loss: 0.0012
# Epoch 526, Loss: 0.0011
# Epoch 527, Loss: 0.0012
# Epoch 528, Loss: 0.0012
# Epoch 529, Loss: 0.0013
# Epoch 530, Loss: 0.0013
# Epoch 531, Loss: 0.0014
# Epoch 532, Loss: 0.0013
# Epoch 533, Loss: 0.0012
# Epoch 534, Loss: 0.0012
# Epoch 535, Loss: 0.0012
# Epoch 536, Loss: 0.0011
# Epoch 537, Loss: 0.0012
# Epoch 538, Loss: 0.0011
# Epoch 539, Loss: 0.0011
# Epoch 540, Loss: 0.0011
# Epoch 541, Loss: 0.0011
# Epoch 542, Loss: 0.0012
# Epoch 543, Loss: 0.0012
# Epoch 544, Loss: 0.0011
# Epoch 545, Loss: 0.0011
# Epoch 546, Loss: 0.0011
# Epoch 547, Loss: 0.0011
# Epoch 548, Loss: 0.0011
# Epoch 549, Loss: 0.0012
# Epoch 550, Loss: 0.0012
# Epoch 551, Loss: 0.0011
# Epoch 552, Loss: 0.0012
# Epoch 553, Loss: 0.0011
# Epoch 554, Loss: 0.0012
# Epoch 555, Loss: 0.0012
# Epoch 556, Loss: 0.0011
# Epoch 557, Loss: 0.0012
# Epoch 558, Loss: 0.0011
# Epoch 559, Loss: 0.0011
# Epoch 560, Loss: 0.0011
# Epoch 561, Loss: 0.0012
# Epoch 562, Loss: 0.0012
# Epoch 563, Loss: 0.0011
# Epoch 564, Loss: 0.0011
# Epoch 565, Loss: 0.0011
# Epoch 566, Loss: 0.0011
# Epoch 567, Loss: 0.0011
# Epoch 568, Loss: 0.0012
# Epoch 569, Loss: 0.0012
# Epoch 570, Loss: 0.0011
# Epoch 571, Loss: 0.0011
# Epoch 572, Loss: 0.0011
# Epoch 573, Loss: 0.0011
# Epoch 574, Loss: 0.0011
# Epoch 575, Loss: 0.0012
# Epoch 576, Loss: 0.0012
# Epoch 577, Loss: 0.0011
# Epoch 578, Loss: 0.0011
# Epoch 579, Loss: 0.0011
# Epoch 580, Loss: 0.0011
# Epoch 581, Loss: 0.0012
# Epoch 582, Loss: 0.0012
# Epoch 583, Loss: 0.0012
# Epoch 584, Loss: 0.0012
# Epoch 585, Loss: 0.0011
# Epoch 586, Loss: 0.0011
# Epoch 587, Loss: 0.0011
# Epoch 588, Loss: 0.0011
# Epoch 589, Loss: 0.0012
# Epoch 590, Loss: 0.0012
# Epoch 591, Loss: 0.0012
# Epoch 592, Loss: 0.0011
# Epoch 593, Loss: 0.0011
# Epoch 594, Loss: 0.0011
# Epoch 595, Loss: 0.0011
# Epoch 596, Loss: 0.0012
# Epoch 597, Loss: 0.0012
# Epoch 598, Loss: 0.0012
# Epoch 599, Loss: 0.0011
# Epoch 600, Loss: 0.0010
# Epoch 601, Loss: 0.0011
# Epoch 602, Loss: 0.0011
# Epoch 603, Loss: 0.0010
# Epoch 604, Loss: 0.0011
# Epoch 605, Loss: 0.0012
# Epoch 606, Loss: 0.0011
# Epoch 607, Loss: 0.0010
# Epoch 608, Loss: 0.0011
# Epoch 609, Loss: 0.0011
# Epoch 610, Loss: 0.0011
# Epoch 611, Loss: 0.0011
# Epoch 612, Loss: 0.0010
# Epoch 613, Loss: 0.0010
# Epoch 614, Loss: 0.0011
# Epoch 615, Loss: 0.0011
# Epoch 616, Loss: 0.0011
# Epoch 617, Loss: 0.0012
# Epoch 618, Loss: 0.0010
# Epoch 619, Loss: 0.0011
# Epoch 620, Loss: 0.0011
# Epoch 621, Loss: 0.0011
# Epoch 622, Loss: 0.0012
# Epoch 623, Loss: 0.0011
# Epoch 624, Loss: 0.0012
# Epoch 625, Loss: 0.0011
# Epoch 626, Loss: 0.0011
# Epoch 627, Loss: 0.0011
# Epoch 628, Loss: 0.0011
# Epoch 629, Loss: 0.0010
# Epoch 630, Loss: 0.0010
# Epoch 631, Loss: 0.0011
# Epoch 632, Loss: 0.0012
# Epoch 633, Loss: 0.0010
# Epoch 634, Loss: 0.0011
# Epoch 635, Loss: 0.0011
# Epoch 636, Loss: 0.0011
# Epoch 637, Loss: 0.0012
# Epoch 638, Loss: 0.0011
# Epoch 639, Loss: 0.0012
# Epoch 640, Loss: 0.0011
# Epoch 641, Loss: 0.0011
# Epoch 642, Loss: 0.0011
# Epoch 643, Loss: 0.0010
# Epoch 644, Loss: 0.0010
# Epoch 645, Loss: 0.0010
# Epoch 646, Loss: 0.0011
# Epoch 647, Loss: 0.0011
# Epoch 648, Loss: 0.0011
# Epoch 649, Loss: 0.0010
# Epoch 650, Loss: 0.0011
# Epoch 651, Loss: 0.0010
# Epoch 652, Loss: 0.0010
# Epoch 653, Loss: 0.0011
# Epoch 654, Loss: 0.0010
# Epoch 655, Loss: 0.0011
# Epoch 656, Loss: 0.0011
# Epoch 657, Loss: 0.0011
# Epoch 658, Loss: 0.0011
# Epoch 659, Loss: 0.0011
# Epoch 660, Loss: 0.0010
# Epoch 661, Loss: 0.0010
# Epoch 662, Loss: 0.0010
# Epoch 663, Loss: 0.0010
# Epoch 664, Loss: 0.0010
# Epoch 665, Loss: 0.0010
# Epoch 666, Loss: 0.0010
# Epoch 667, Loss: 0.0011
# Epoch 668, Loss: 0.0011
# Epoch 669, Loss: 0.0013
# Epoch 670, Loss: 0.0013
# Epoch 671, Loss: 0.0011
# Epoch 672, Loss: 0.0011
# Epoch 673, Loss: 0.0010
# Epoch 674, Loss: 0.0010
# Epoch 675, Loss: 0.0010
# Epoch 676, Loss: 0.0010
# Epoch 677, Loss: 0.0012
# Epoch 678, Loss: 0.0011
# Epoch 679, Loss: 0.0010
# Epoch 680, Loss: 0.0010
# Epoch 681, Loss: 0.0011
# Epoch 682, Loss: 0.0011
# Epoch 683, Loss: 0.0010
# Epoch 684, Loss: 0.0010
# Epoch 685, Loss: 0.0010
# Epoch 686, Loss: 0.0010
# Epoch 687, Loss: 0.0010
# Epoch 688, Loss: 0.0011
# Epoch 689, Loss: 0.0011
# Epoch 690, Loss: 0.0011
# Epoch 691, Loss: 0.0011
# Epoch 692, Loss: 0.0011
# Epoch 693, Loss: 0.0012
# Epoch 694, Loss: 0.0011
# Epoch 695, Loss: 0.0011
# Epoch 696, Loss: 0.0012
# Epoch 697, Loss: 0.0010
# Epoch 698, Loss: 0.0011
# Epoch 699, Loss: 0.0010
# Epoch 700, Loss: 0.0010
# Epoch 701, Loss: 0.0010
# Epoch 702, Loss: 0.0010
# Epoch 703, Loss: 0.0011
# Epoch 704, Loss: 0.0010
# Epoch 705, Loss: 0.0010
# Epoch 706, Loss: 0.0010
# Epoch 707, Loss: 0.0010
# Epoch 708, Loss: 0.0010
# Epoch 709, Loss: 0.0011
# Epoch 710, Loss: 0.0010
# Epoch 711, Loss: 0.0011
# Epoch 712, Loss: 0.0011
# Epoch 713, Loss: 0.0010
# Epoch 714, Loss: 0.0009
# Epoch 715, Loss: 0.0010
# Epoch 716, Loss: 0.0011
# Epoch 717, Loss: 0.0010
# Epoch 718, Loss: 0.0009
# Epoch 719, Loss: 0.0009
# Epoch 720, Loss: 0.0010
# Epoch 721, Loss: 0.0011
# Epoch 722, Loss: 0.0010
# Epoch 723, Loss: 0.0010
# Epoch 724, Loss: 0.0011
# Epoch 725, Loss: 0.0011
# Epoch 726, Loss: 0.0012
# Epoch 727, Loss: 0.0011
# Epoch 728, Loss: 0.0010
# Epoch 729, Loss: 0.0012
# Epoch 730, Loss: 0.0010
# Epoch 731, Loss: 0.0010
# Epoch 732, Loss: 0.0009
# Epoch 733, Loss: 0.0010
# Epoch 734, Loss: 0.0009
# Epoch 735, Loss: 0.0010
# Epoch 736, Loss: 0.0010
# Epoch 737, Loss: 0.0010
# Epoch 738, Loss: 0.0010
# Epoch 739, Loss: 0.0011
# Epoch 740, Loss: 0.0011
# Epoch 741, Loss: 0.0010
# Epoch 742, Loss: 0.0010
# Epoch 743, Loss: 0.0010
# Epoch 744, Loss: 0.0010
# Epoch 745, Loss: 0.0011
# Epoch 746, Loss: 0.0010
# Epoch 747, Loss: 0.0010
# Epoch 748, Loss: 0.0010
# Epoch 749, Loss: 0.0011
# Epoch 750, Loss: 0.0010
# Epoch 751, Loss: 0.0010
# Epoch 752, Loss: 0.0010
# Epoch 753, Loss: 0.0010
# Epoch 754, Loss: 0.0010
# Epoch 755, Loss: 0.0010
# Epoch 756, Loss: 0.0010
# Epoch 757, Loss: 0.0010
# Epoch 758, Loss: 0.0009
# Epoch 759, Loss: 0.0010
# Epoch 760, Loss: 0.0011
# Epoch 761, Loss: 0.0010
# Epoch 762, Loss: 0.0010
# Epoch 763, Loss: 0.0010
# Epoch 764, Loss: 0.0011
# Epoch 765, Loss: 0.0010
# Epoch 766, Loss: 0.0010
# Epoch 767, Loss: 0.0009
# Epoch 768, Loss: 0.0010
# Epoch 769, Loss: 0.0009
# Epoch 770, Loss: 0.0009
# Epoch 771, Loss: 0.0010
# Epoch 772, Loss: 0.0012
# Epoch 773, Loss: 0.0011
# Epoch 774, Loss: 0.0011
# Epoch 775, Loss: 0.0011
# Epoch 776, Loss: 0.0012
# Epoch 777, Loss: 0.0011
# Epoch 778, Loss: 0.0011
# Epoch 779, Loss: 0.0010
# Epoch 780, Loss: 0.0010
# Epoch 781, Loss: 0.0010
# Epoch 782, Loss: 0.0011
# Epoch 783, Loss: 0.0010
# Epoch 784, Loss: 0.0010
# Epoch 785, Loss: 0.0010
# Epoch 786, Loss: 0.0010
# Epoch 787, Loss: 0.0010
# Epoch 788, Loss: 0.0010
# Epoch 789, Loss: 0.0009
# Epoch 790, Loss: 0.0010
# Epoch 791, Loss: 0.0010
# Epoch 792, Loss: 0.0009
# Epoch 793, Loss: 0.0009
# Epoch 794, Loss: 0.0010
# Epoch 795, Loss: 0.0009
# Epoch 796, Loss: 0.0010
# Epoch 797, Loss: 0.0011
# Epoch 798, Loss: 0.0010
# Epoch 799, Loss: 0.0010
# Epoch 800, Loss: 0.0011
# Epoch 801, Loss: 0.0010
# Epoch 802, Loss: 0.0009
# Epoch 803, Loss: 0.0009
# Epoch 804, Loss: 0.0011
# Epoch 805, Loss: 0.0011
# Epoch 806, Loss: 0.0010
# Epoch 807, Loss: 0.0009
# Epoch 808, Loss: 0.0009
# Epoch 809, Loss: 0.0009
# Epoch 810, Loss: 0.0010
# Epoch 811, Loss: 0.0010
# Epoch 812, Loss: 0.0011
# Epoch 813, Loss: 0.0010
# Epoch 814, Loss: 0.0009
# Epoch 815, Loss: 0.0009
# Epoch 816, Loss: 0.0009
# Epoch 817, Loss: 0.0010
# Epoch 818, Loss: 0.0010
# Epoch 819, Loss: 0.0010
# Epoch 820, Loss: 0.0010
# Epoch 821, Loss: 0.0009
# Epoch 822, Loss: 0.0009
# Epoch 823, Loss: 0.0010
# Epoch 824, Loss: 0.0009
# Epoch 825, Loss: 0.0010
# Epoch 826, Loss: 0.0009
# Epoch 827, Loss: 0.0009
# Epoch 828, Loss: 0.0009
# Epoch 829, Loss: 0.0010
# Epoch 830, Loss: 0.0009
# Epoch 831, Loss: 0.0010
# Epoch 832, Loss: 0.0009
# Epoch 833, Loss: 0.0009
# Epoch 834, Loss: 0.0009
# Epoch 835, Loss: 0.0009
# Epoch 836, Loss: 0.0011
# Epoch 837, Loss: 0.0010
# Epoch 838, Loss: 0.0009
# Epoch 839, Loss: 0.0010
# Epoch 840, Loss: 0.0009
# Epoch 841, Loss: 0.0010
# Epoch 842, Loss: 0.0010
# Epoch 843, Loss: 0.0010
# Epoch 844, Loss: 0.0010
# Epoch 845, Loss: 0.0009
# Epoch 846, Loss: 0.0009
# Epoch 847, Loss: 0.0009
# Epoch 848, Loss: 0.0010
# Epoch 849, Loss: 0.0009
# Epoch 850, Loss: 0.0009
# Epoch 851, Loss: 0.0010
# Epoch 852, Loss: 0.0012
# Epoch 853, Loss: 0.0010
# Epoch 854, Loss: 0.0011
# Epoch 855, Loss: 0.0010
# Epoch 856, Loss: 0.0010
# Epoch 857, Loss: 0.0010
# Epoch 858, Loss: 0.0009
# Epoch 859, Loss: 0.0009
# Epoch 860, Loss: 0.0009
# Epoch 861, Loss: 0.0009
# Epoch 862, Loss: 0.0009
# Epoch 863, Loss: 0.0011
# Epoch 864, Loss: 0.0011
# Epoch 865, Loss: 0.0010
# Epoch 866, Loss: 0.0009
# Epoch 867, Loss: 0.0009
# Epoch 868, Loss: 0.0009
# Epoch 869, Loss: 0.0010
# Epoch 870, Loss: 0.0010
# Epoch 871, Loss: 0.0010
# Epoch 872, Loss: 0.0009
# Epoch 873, Loss: 0.0011
# Epoch 874, Loss: 0.0010
# Epoch 875, Loss: 0.0010
# Epoch 876, Loss: 0.0010
# Epoch 877, Loss: 0.0010
# Epoch 878, Loss: 0.0010
# Epoch 879, Loss: 0.0010
# Epoch 880, Loss: 0.0010
# Epoch 881, Loss: 0.0010
# Epoch 882, Loss: 0.0010
# Epoch 883, Loss: 0.0009
# Epoch 884, Loss: 0.0010
# Epoch 885, Loss: 0.0010
# Epoch 886, Loss: 0.0009
# Epoch 887, Loss: 0.0009
# Epoch 888, Loss: 0.0009
# Epoch 889, Loss: 0.0009
# Epoch 890, Loss: 0.0010
# Epoch 891, Loss: 0.0010
# Epoch 892, Loss: 0.0009
# Epoch 893, Loss: 0.0009
# Epoch 894, Loss: 0.0009
# Epoch 895, Loss: 0.0010
# Epoch 896, Loss: 0.0012
# Epoch 897, Loss: 0.0009
# Epoch 898, Loss: 0.0009
# Epoch 899, Loss: 0.0009
# Epoch 900, Loss: 0.0009
# Epoch 901, Loss: 0.0009
# Epoch 902, Loss: 0.0009
# Epoch 903, Loss: 0.0009
# Epoch 904, Loss: 0.0009
# Epoch 905, Loss: 0.0009
# Epoch 906, Loss: 0.0010
# Epoch 907, Loss: 0.0010
# Epoch 908, Loss: 0.0010
# Epoch 909, Loss: 0.0009
# Epoch 910, Loss: 0.0010
# Epoch 911, Loss: 0.0011
# Epoch 912, Loss: 0.0010
# Epoch 913, Loss: 0.0010
# Epoch 914, Loss: 0.0010
# Epoch 915, Loss: 0.0009
# Epoch 916, Loss: 0.0009
# Epoch 917, Loss: 0.0009
# Epoch 918, Loss: 0.0010
# Epoch 919, Loss: 0.0010
# Epoch 920, Loss: 0.0009
# Epoch 921, Loss: 0.0009
# Epoch 922, Loss: 0.0009
# Epoch 923, Loss: 0.0009
# Epoch 924, Loss: 0.0010
# Epoch 925, Loss: 0.0009
# Epoch 926, Loss: 0.0008
# Epoch 927, Loss: 0.0008
# Epoch 928, Loss: 0.0009
# Epoch 929, Loss: 0.0009
# Epoch 930, Loss: 0.0009
# Epoch 931, Loss: 0.0010
# Epoch 932, Loss: 0.0009
# Epoch 933, Loss: 0.0010
# Epoch 934, Loss: 0.0010
# Epoch 935, Loss: 0.0010
# Epoch 936, Loss: 0.0011
# Epoch 937, Loss: 0.0009
# Epoch 938, Loss: 0.0008
# Epoch 939, Loss: 0.0009
# Epoch 940, Loss: 0.0009
# Epoch 941, Loss: 0.0010
# Epoch 942, Loss: 0.0010
# Epoch 943, Loss: 0.0009
# Epoch 944, Loss: 0.0010
# Epoch 945, Loss: 0.0010
# Epoch 946, Loss: 0.0009
# Epoch 947, Loss: 0.0009
# Epoch 948, Loss: 0.0010
# Epoch 949, Loss: 0.0009
# Epoch 950, Loss: 0.0010
# Epoch 951, Loss: 0.0008
# Epoch 952, Loss: 0.0008
# Epoch 953, Loss: 0.0009
# Epoch 954, Loss: 0.0008
# Epoch 955, Loss: 0.0008
# Epoch 956, Loss: 0.0008
# Epoch 957, Loss: 0.0009
# Epoch 958, Loss: 0.0009
# Epoch 959, Loss: 0.0010
# Epoch 960, Loss: 0.0010
# Epoch 961, Loss: 0.0010
# Epoch 962, Loss: 0.0009
# Epoch 963, Loss: 0.0009
# Epoch 964, Loss: 0.0010
# Epoch 965, Loss: 0.0012
# Epoch 966, Loss: 0.0011
# Epoch 967, Loss: 0.0010
# Epoch 968, Loss: 0.0010
# Epoch 969, Loss: 0.0010
# Epoch 970, Loss: 0.0009
# Epoch 971, Loss: 0.0010
# Epoch 972, Loss: 0.0009
# Epoch 973, Loss: 0.0009
# Epoch 974, Loss: 0.0009
# Epoch 975, Loss: 0.0009
# Epoch 976, Loss: 0.0009
# Epoch 977, Loss: 0.0008
# Epoch 978, Loss: 0.0009
# Epoch 979, Loss: 0.0009
# Epoch 980, Loss: 0.0009
# Epoch 981, Loss: 0.0009
# Epoch 982, Loss: 0.0009
# Epoch 983, Loss: 0.0009
# Epoch 984, Loss: 0.0009
# Epoch 985, Loss: 0.0008
# Epoch 986, Loss: 0.0008
# Epoch 987, Loss: 0.0009
# Epoch 988, Loss: 0.0009
# Epoch 989, Loss: 0.0009
# Epoch 990, Loss: 0.0009
# Epoch 991, Loss: 0.0009
# Epoch 992, Loss: 0.0009
# Epoch 993, Loss: 0.0009
# Epoch 994, Loss: 0.0009
# Epoch 995, Loss: 0.0010
# Epoch 996, Loss: 0.0009
# Epoch 997, Loss: 0.0009
# Epoch 998, Loss: 0.0009
# Epoch 999, Loss: 0.0009
# Epoch 1000, Loss: 0.0009
# Epoch 1001, Loss: 0.0008
# Epoch 1002, Loss: 0.0009
# Epoch 1003, Loss: 0.0008
# Epoch 1004, Loss: 0.0009
# Epoch 1005, Loss: 0.0010
# Epoch 1006, Loss: 0.0009
# Epoch 1007, Loss: 0.0009
# Epoch 1008, Loss: 0.0010
# Epoch 1009, Loss: 0.0009
# Epoch 1010, Loss: 0.0009
# Epoch 1011, Loss: 0.0008
# Epoch 1012, Loss: 0.0009
# Epoch 1013, Loss: 0.0009
# Epoch 1014, Loss: 0.0009
# Epoch 1015, Loss: 0.0008
# Epoch 1016, Loss: 0.0009
# Epoch 1017, Loss: 0.0010
# Epoch 1018, Loss: 0.0010
# Epoch 1019, Loss: 0.0008
# Epoch 1020, Loss: 0.0008
# Epoch 1021, Loss: 0.0009
# Epoch 1022, Loss: 0.0009
# Epoch 1023, Loss: 0.0008
# Epoch 1024, Loss: 0.0008
# Epoch 1025, Loss: 0.0008
# Epoch 1026, Loss: 0.0009
# Epoch 1027, Loss: 0.0010
# Epoch 1028, Loss: 0.0010
# Epoch 1029, Loss: 0.0009
# Epoch 1030, Loss: 0.0008
# Epoch 1031, Loss: 0.0009
# Epoch 1032, Loss: 0.0009
# Epoch 1033, Loss: 0.0009
# Epoch 1034, Loss: 0.0009
# Epoch 1035, Loss: 0.0009
# Epoch 1036, Loss: 0.0010
# Epoch 1037, Loss: 0.0009
# Epoch 1038, Loss: 0.0009
# Epoch 1039, Loss: 0.0009
# Epoch 1040, Loss: 0.0009
# Epoch 1041, Loss: 0.0009
# Epoch 1042, Loss: 0.0009
# Epoch 1043, Loss: 0.0009
# Epoch 1044, Loss: 0.0009
# Epoch 1045, Loss: 0.0010
# Epoch 1046, Loss: 0.0010
# Epoch 1047, Loss: 0.0010
# Epoch 1048, Loss: 0.0009
# Epoch 1049, Loss: 0.0008
# Epoch 1050, Loss: 0.0008
# Epoch 1051, Loss: 0.0008
# Epoch 1052, Loss: 0.0008
# Epoch 1053, Loss: 0.0008
# Epoch 1054, Loss: 0.0009
# Epoch 1055, Loss: 0.0010
# Epoch 1056, Loss: 0.0008
# Epoch 1057, Loss: 0.0009
# Epoch 1058, Loss: 0.0009
# Epoch 1059, Loss: 0.0008
# Epoch 1060, Loss: 0.0009
# Epoch 1061, Loss: 0.0010
# Epoch 1062, Loss: 0.0008
# Epoch 1063, Loss: 0.0010
# Epoch 1064, Loss: 0.0009
# Epoch 1065, Loss: 0.0008
# Epoch 1066, Loss: 0.0009
# Epoch 1067, Loss: 0.0008
# Epoch 1068, Loss: 0.0008
# Epoch 1069, Loss: 0.0009
# Epoch 1070, Loss: 0.0009
# Epoch 1071, Loss: 0.0009
# Epoch 1072, Loss: 0.0008
# Epoch 1073, Loss: 0.0008
# Epoch 1074, Loss: 0.0008
# Epoch 1075, Loss: 0.0008
# Epoch 1076, Loss: 0.0008
# Epoch 1077, Loss: 0.0009
# Epoch 1078, Loss: 0.0008
# Epoch 1079, Loss: 0.0008
# Epoch 1080, Loss: 0.0008
# Epoch 1081, Loss: 0.0008
# Epoch 1082, Loss: 0.0010
# Epoch 1083, Loss: 0.0011
# Epoch 1084, Loss: 0.0009
# Epoch 1085, Loss: 0.0009
# Epoch 1086, Loss: 0.0008
# Epoch 1087, Loss: 0.0008
# Epoch 1088, Loss: 0.0008
# Epoch 1089, Loss: 0.0009
# Epoch 1090, Loss: 0.0008
# Epoch 1091, Loss: 0.0009
# Epoch 1092, Loss: 0.0009
# Epoch 1093, Loss: 0.0010
# Epoch 1094, Loss: 0.0008
# Epoch 1095, Loss: 0.0008
# Epoch 1096, Loss: 0.0008
# Epoch 1097, Loss: 0.0008
# Epoch 1098, Loss: 0.0009
# Epoch 1099, Loss: 0.0008
# Epoch 1100, Loss: 0.0008
# Epoch 1101, Loss: 0.0008
# Epoch 1102, Loss: 0.0009
# Epoch 1103, Loss: 0.0008
# Epoch 1104, Loss: 0.0008
# Epoch 1105, Loss: 0.0008
# Epoch 1106, Loss: 0.0008
# Epoch 1107, Loss: 0.0008
# Epoch 1108, Loss: 0.0009
# Epoch 1109, Loss: 0.0008
# Epoch 1110, Loss: 0.0008
# Epoch 1111, Loss: 0.0008
# Epoch 1112, Loss: 0.0008
# Epoch 1113, Loss: 0.0008
# Epoch 1114, Loss: 0.0009
# Epoch 1115, Loss: 0.0009
# Epoch 1116, Loss: 0.0009
# Epoch 1117, Loss: 0.0008
# Epoch 1118, Loss: 0.0009
# Epoch 1119, Loss: 0.0009
# Epoch 1120, Loss: 0.0012
# Epoch 1121, Loss: 0.0010
# Epoch 1122, Loss: 0.0008
# Epoch 1123, Loss: 0.0008
# Epoch 1124, Loss: 0.0008
# Epoch 1125, Loss: 0.0008
# Epoch 1126, Loss: 0.0008
# Epoch 1127, Loss: 0.0008
# Epoch 1128, Loss: 0.0008
# Epoch 1129, Loss: 0.0008
# Epoch 1130, Loss: 0.0008
# Epoch 1131, Loss: 0.0009
# Epoch 1132, Loss: 0.0009
# Epoch 1133, Loss: 0.0009
# Epoch 1134, Loss: 0.0008
# Epoch 1135, Loss: 0.0008
# Epoch 1136, Loss: 0.0009
# Epoch 1137, Loss: 0.0010
# Epoch 1138, Loss: 0.0009
# Epoch 1139, Loss: 0.0008
# Epoch 1140, Loss: 0.0008
# Epoch 1141, Loss: 0.0008
# Epoch 1142, Loss: 0.0008
# Epoch 1143, Loss: 0.0008
# Epoch 1144, Loss: 0.0009
# Epoch 1145, Loss: 0.0008
# Epoch 1146, Loss: 0.0008
# Epoch 1147, Loss: 0.0009
# Epoch 1148, Loss: 0.0008
# Epoch 1149, Loss: 0.0008
# Epoch 1150, Loss: 0.0008
# Epoch 1151, Loss: 0.0008
# Epoch 1152, Loss: 0.0008
# Epoch 1153, Loss: 0.0011
# Epoch 1154, Loss: 0.0009
# Epoch 1155, Loss: 0.0008
# Epoch 1156, Loss: 0.0009
# Epoch 1157, Loss: 0.0009
# Epoch 1158, Loss: 0.0009
# Epoch 1159, Loss: 0.0008
# Epoch 1160, Loss: 0.0008
# Epoch 1161, Loss: 0.0008
# Epoch 1162, Loss: 0.0008
# Epoch 1163, Loss: 0.0008
# Epoch 1164, Loss: 0.0008
# Epoch 1165, Loss: 0.0008
# Epoch 1166, Loss: 0.0008
# Epoch 1167, Loss: 0.0008
# Epoch 1168, Loss: 0.0010
# Epoch 1169, Loss: 0.0009
# Epoch 1170, Loss: 0.0008
# Epoch 1171, Loss: 0.0008
# Epoch 1172, Loss: 0.0008
# Epoch 1173, Loss: 0.0008
# Epoch 1174, Loss: 0.0008
# Epoch 1175, Loss: 0.0008
# Epoch 1176, Loss: 0.0008
# Epoch 1177, Loss: 0.0008
# Epoch 1178, Loss: 0.0007
# Epoch 1179, Loss: 0.0008
# Epoch 1180, Loss: 0.0008
# Epoch 1181, Loss: 0.0008
# Epoch 1182, Loss: 0.0007
# Epoch 1183, Loss: 0.0008
# Epoch 1184, Loss: 0.0009
# Epoch 1185, Loss: 0.0008
# Epoch 1186, Loss: 0.0008
# Epoch 1187, Loss: 0.0009
# Epoch 1188, Loss: 0.0009
# Epoch 1189, Loss: 0.0008
# Epoch 1190, Loss: 0.0008
# Epoch 1191, Loss: 0.0008
# Epoch 1192, Loss: 0.0008
# Epoch 1193, Loss: 0.0009
# Epoch 1194, Loss: 0.0009
# Epoch 1195, Loss: 0.0008
# Epoch 1196, Loss: 0.0008
# Epoch 1197, Loss: 0.0008
# Epoch 1198, Loss: 0.0008
# Epoch 1199, Loss: 0.0009
# Epoch 1200, Loss: 0.0008
# Epoch 1201, Loss: 0.0008
# Epoch 1202, Loss: 0.0008
# Epoch 1203, Loss: 0.0008
# Epoch 1204, Loss: 0.0008
# Epoch 1205, Loss: 0.0007
# Epoch 1206, Loss: 0.0007
# Epoch 1207, Loss: 0.0008
# Epoch 1208, Loss: 0.0008
# Epoch 1209, Loss: 0.0007
# Epoch 1210, Loss: 0.0008
# Epoch 1211, Loss: 0.0008
# Epoch 1212, Loss: 0.0008
# Epoch 1213, Loss: 0.0008
# Epoch 1214, Loss: 0.0008
# Epoch 1215, Loss: 0.0008
# Epoch 1216, Loss: 0.0008
# Epoch 1217, Loss: 0.0008
# Epoch 1218, Loss: 0.0008
# Epoch 1219, Loss: 0.0008
# Epoch 1220, Loss: 0.0009
# Epoch 1221, Loss: 0.0009
# Epoch 1222, Loss: 0.0007
# Epoch 1223, Loss: 0.0009
# Epoch 1224, Loss: 0.0008
# Epoch 1225, Loss: 0.0010
# Epoch 1226, Loss: 0.0009
# Epoch 1227, Loss: 0.0008
# Epoch 1228, Loss: 0.0008
# Epoch 1229, Loss: 0.0008
# Epoch 1230, Loss: 0.0008
# Epoch 1231, Loss: 0.0008
# Epoch 1232, Loss: 0.0008
# Epoch 1233, Loss: 0.0007
# Epoch 1234, Loss: 0.0008
# Epoch 1235, Loss: 0.0010
# Epoch 1236, Loss: 0.0009
# Epoch 1237, Loss: 0.0008
# Epoch 1238, Loss: 0.0007
# Epoch 1239, Loss: 0.0007
# Epoch 1240, Loss: 0.0007
# Epoch 1241, Loss: 0.0007
# Epoch 1242, Loss: 0.0008
# Epoch 1243, Loss: 0.0008
# Epoch 1244, Loss: 0.0008
# Epoch 1245, Loss: 0.0008
# Epoch 1246, Loss: 0.0008
# Epoch 1247, Loss: 0.0007
# Epoch 1248, Loss: 0.0008
# Epoch 1249, Loss: 0.0009
# Epoch 1250, Loss: 0.0008
# Epoch 1251, Loss: 0.0008
# Epoch 1252, Loss: 0.0008
# Epoch 1253, Loss: 0.0007
# Epoch 1254, Loss: 0.0008
# Epoch 1255, Loss: 0.0009
# Epoch 1256, Loss: 0.0008
# Epoch 1257, Loss: 0.0008
# Epoch 1258, Loss: 0.0008
# Epoch 1259, Loss: 0.0008
# Epoch 1260, Loss: 0.0007
# Epoch 1261, Loss: 0.0007
# Epoch 1262, Loss: 0.0008
# Epoch 1263, Loss: 0.0008
# Epoch 1264, Loss: 0.0009
# Epoch 1265, Loss: 0.0009
# Epoch 1266, Loss: 0.0008
# Epoch 1267, Loss: 0.0008
# Epoch 1268, Loss: 0.0008
# Epoch 1269, Loss: 0.0008
# Epoch 1270, Loss: 0.0008
# Epoch 1271, Loss: 0.0008
# Epoch 1272, Loss: 0.0008
# Epoch 1273, Loss: 0.0008
# Epoch 1274, Loss: 0.0008
# Epoch 1275, Loss: 0.0008
# Epoch 1276, Loss: 0.0007
# Epoch 1277, Loss: 0.0007
# Epoch 1278, Loss: 0.0008
# Epoch 1279, Loss: 0.0008
# Epoch 1280, Loss: 0.0008
# Epoch 1281, Loss: 0.0008
# Epoch 1282, Loss: 0.0009
# Epoch 1283, Loss: 0.0008
# Epoch 1284, Loss: 0.0008
# Epoch 1285, Loss: 0.0009
# Epoch 1286, Loss: 0.0008
# Epoch 1287, Loss: 0.0007
# Epoch 1288, Loss: 0.0007
# Epoch 1289, Loss: 0.0008
# Epoch 1290, Loss: 0.0007
# Epoch 1291, Loss: 0.0008
# Epoch 1292, Loss: 0.0008
# Epoch 1293, Loss: 0.0007
# Epoch 1294, Loss: 0.0007
# Epoch 1295, Loss: 0.0008
# Epoch 1296, Loss: 0.0008
# Epoch 1297, Loss: 0.0007
# Epoch 1298, Loss: 0.0007
# Epoch 1299, Loss: 0.0007
# Epoch 1300, Loss: 0.0007
# Epoch 1301, Loss: 0.0008
# Epoch 1302, Loss: 0.0007
# Epoch 1303, Loss: 0.0007
# Epoch 1304, Loss: 0.0007
# Epoch 1305, Loss: 0.0007
# Epoch 1306, Loss: 0.0007
# Epoch 1307, Loss: 0.0007
# Epoch 1308, Loss: 0.0007
# Epoch 1309, Loss: 0.0008
# Epoch 1310, Loss: 0.0007
# Epoch 1311, Loss: 0.0007
# Epoch 1312, Loss: 0.0008
# Epoch 1313, Loss: 0.0007
# Epoch 1314, Loss: 0.0007
# Epoch 1315, Loss: 0.0008
# Epoch 1316, Loss: 0.0008
# Epoch 1317, Loss: 0.0007
# Epoch 1318, Loss: 0.0009
# Epoch 1319, Loss: 0.0008
# Epoch 1320, Loss: 0.0007
# Epoch 1321, Loss: 0.0007
# Epoch 1322, Loss: 0.0007
# Epoch 1323, Loss: 0.0009
# Epoch 1324, Loss: 0.0008
# Epoch 1325, Loss: 0.0008
# Epoch 1326, Loss: 0.0008
# Epoch 1327, Loss: 0.0008
# Epoch 1328, Loss: 0.0008
# Epoch 1329, Loss: 0.0008
# Epoch 1330, Loss: 0.0008
# Epoch 1331, Loss: 0.0008
# Epoch 1332, Loss: 0.0008
# Epoch 1333, Loss: 0.0008
# Epoch 1334, Loss: 0.0008
# Epoch 1335, Loss: 0.0008
# Epoch 1336, Loss: 0.0007
# Epoch 1337, Loss: 0.0008
# Epoch 1338, Loss: 0.0008
# Epoch 1339, Loss: 0.0007
# Epoch 1340, Loss: 0.0009
# Epoch 1341, Loss: 0.0009
# Epoch 1342, Loss: 0.0009
# Epoch 1343, Loss: 0.0007
# Epoch 1344, Loss: 0.0007
# Epoch 1345, Loss: 0.0007
# Epoch 1346, Loss: 0.0007
# Epoch 1347, Loss: 0.0008
# Epoch 1348, Loss: 0.0007
# Epoch 1349, Loss: 0.0007
# Epoch 1350, Loss: 0.0007
# Epoch 1351, Loss: 0.0007
# Epoch 1352, Loss: 0.0008
# Epoch 1353, Loss: 0.0007
# Epoch 1354, Loss: 0.0009
# Epoch 1355, Loss: 0.0008
# Epoch 1356, Loss: 0.0008
# Epoch 1357, Loss: 0.0008
# Epoch 1358, Loss: 0.0007
# Epoch 1359, Loss: 0.0008
# Epoch 1360, Loss: 0.0007
# Epoch 1361, Loss: 0.0008
# Epoch 1362, Loss: 0.0007
# Epoch 1363, Loss: 0.0007
# Epoch 1364, Loss: 0.0008
# Epoch 1365, Loss: 0.0007
# Epoch 1366, Loss: 0.0007
# Epoch 1367, Loss: 0.0007
# Epoch 1368, Loss: 0.0007
# Epoch 1369, Loss: 0.0007
# Epoch 1370, Loss: 0.0007
# Epoch 1371, Loss: 0.0008
# Epoch 1372, Loss: 0.0008
# Epoch 1373, Loss: 0.0008
# Epoch 1374, Loss: 0.0009
# Epoch 1375, Loss: 0.0007
# Epoch 1376, Loss: 0.0007
# Epoch 1377, Loss: 0.0007
# Epoch 1378, Loss: 0.0007
# Epoch 1379, Loss: 0.0008
# Epoch 1380, Loss: 0.0007
# Epoch 1381, Loss: 0.0007
# Epoch 1382, Loss: 0.0008
# Epoch 1383, Loss: 0.0007
# Epoch 1384, Loss: 0.0007
# Epoch 1385, Loss: 0.0007
# Epoch 1386, Loss: 0.0008
# Epoch 1387, Loss: 0.0007
# Epoch 1388, Loss: 0.0008
# Epoch 1389, Loss: 0.0008
# Epoch 1390, Loss: 0.0008
# Epoch 1391, Loss: 0.0009
# Epoch 1392, Loss: 0.0010
# Epoch 1393, Loss: 0.0010
# Epoch 1394, Loss: 0.0008
# Epoch 1395, Loss: 0.0007
# Epoch 1396, Loss: 0.0008
# Epoch 1397, Loss: 0.0009
# Epoch 1398, Loss: 0.0008
# Epoch 1399, Loss: 0.0008
# Epoch 1400, Loss: 0.0007
# Epoch 1401, Loss: 0.0007
# Epoch 1402, Loss: 0.0008
# Epoch 1403, Loss: 0.0008
# Epoch 1404, Loss: 0.0008
# Epoch 1405, Loss: 0.0007
# Epoch 1406, Loss: 0.0007
# Epoch 1407, Loss: 0.0008
# Epoch 1408, Loss: 0.0007
# Epoch 1409, Loss: 0.0008
# Epoch 1410, Loss: 0.0007
# Epoch 1411, Loss: 0.0007
# Epoch 1412, Loss: 0.0007
# Epoch 1413, Loss: 0.0007
# Epoch 1414, Loss: 0.0007
# Epoch 1415, Loss: 0.0007
# Epoch 1416, Loss: 0.0007
# Epoch 1417, Loss: 0.0007
# Epoch 1418, Loss: 0.0007
# Epoch 1419, Loss: 0.0008
# Epoch 1420, Loss: 0.0007
# Epoch 1421, Loss: 0.0007
# Epoch 1422, Loss: 0.0007
# Epoch 1423, Loss: 0.0007
# Epoch 1424, Loss: 0.0007
# Epoch 1425, Loss: 0.0007
# Epoch 1426, Loss: 0.0007
# Epoch 1427, Loss: 0.0007
# Epoch 1428, Loss: 0.0007
# Epoch 1429, Loss: 0.0007
# Epoch 1430, Loss: 0.0007
# Epoch 1431, Loss: 0.0007
# Epoch 1432, Loss: 0.0007
# Epoch 1433, Loss: 0.0007
# Epoch 1434, Loss: 0.0007
# Epoch 1435, Loss: 0.0007
# Epoch 1436, Loss: 0.0007
# Epoch 1437, Loss: 0.0007
# Epoch 1438, Loss: 0.0007
# Epoch 1439, Loss: 0.0007
# Epoch 1440, Loss: 0.0008
# Epoch 1441, Loss: 0.0008
# Epoch 1442, Loss: 0.0007
# Epoch 1443, Loss: 0.0007
# Epoch 1444, Loss: 0.0007
# Epoch 1445, Loss: 0.0007
# Epoch 1446, Loss: 0.0007
# Epoch 1447, Loss: 0.0007
# Epoch 1448, Loss: 0.0007
# Epoch 1449, Loss: 0.0007
# Epoch 1450, Loss: 0.0009
# Epoch 1451, Loss: 0.0008
# Epoch 1452, Loss: 0.0008
# Epoch 1453, Loss: 0.0007
# Epoch 1454, Loss: 0.0008
# Epoch 1455, Loss: 0.0007
# Epoch 1456, Loss: 0.0007
# Epoch 1457, Loss: 0.0007
# Epoch 1458, Loss: 0.0007
# Epoch 1459, Loss: 0.0007
# Epoch 1460, Loss: 0.0007
# Epoch 1461, Loss: 0.0008
# Epoch 1462, Loss: 0.0008
# Epoch 1463, Loss: 0.0008
# Epoch 1464, Loss: 0.0008
# Epoch 1465, Loss: 0.0007
# Epoch 1466, Loss: 0.0007
# Epoch 1467, Loss: 0.0007
# Epoch 1468, Loss: 0.0007
# Epoch 1469, Loss: 0.0007
# Epoch 1470, Loss: 0.0007
# Epoch 1471, Loss: 0.0006
# Epoch 1472, Loss: 0.0007
# Epoch 1473, Loss: 0.0008
# Epoch 1474, Loss: 0.0007
# Epoch 1475, Loss: 0.0007
# Epoch 1476, Loss: 0.0007
# Epoch 1477, Loss: 0.0007
# Epoch 1478, Loss: 0.0006
# Epoch 1479, Loss: 0.0006
# Epoch 1480, Loss: 0.0007
# Epoch 1481, Loss: 0.0007
# Epoch 1482, Loss: 0.0007
# Epoch 1483, Loss: 0.0007
# Epoch 1484, Loss: 0.0007
# Epoch 1485, Loss: 0.0006
# Epoch 1486, Loss: 0.0007
# Epoch 1487, Loss: 0.0007
# Epoch 1488, Loss: 0.0009
# Epoch 1489, Loss: 0.0007
# Epoch 1490, Loss: 0.0008
# Epoch 1491, Loss: 0.0006
# Epoch 1492, Loss: 0.0007
# Epoch 1493, Loss: 0.0007
# Epoch 1494, Loss: 0.0007
# Epoch 1495, Loss: 0.0007
# Epoch 1496, Loss: 0.0008
# Epoch 1497, Loss: 0.0007
# Epoch 1498, Loss: 0.0007
# Epoch 1499, Loss: 0.0007
# Epoch 1500, Loss: 0.0007

# %%
from sklearn.metrics import mean_absolute_error, r2_score

def mean_absolute_percentage_error(y_true, y_pred):
    epsilon = 1e-8
    return np.mean(np.abs((y_true - y_pred) / (np.abs(y_true) + epsilon))) * 100

model.eval()
y_pred_all, y_true_all = [], []

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x = batch_x.to(device)
        output = model(batch_x).cpu().numpy()
        y_pred_all.append(output)
        y_true_all.append(batch_y.numpy())

y_pred_all = np.concatenate(y_pred_all, axis=0)
y_true_all = np.concatenate(y_true_all, axis=0)


# After collecting predictions and targets
y_pred_all = scaler.inverse_transform(y_pred_all)
y_true_all = scaler.inverse_transform(y_true_all)


# # Metrics
# mse = np.mean((y_true_all - y_pred_all)**2)
# mae = mean_absolute_error(y_true_all, y_pred_all)
# mape = mean_absolute_percentage_error(y_true_all, y_pred_all)
# r2 = r2_score(y_true_all, y_pred_all)

# print(f"Test MSE:  {mse:.4f}")
# print(f"Test MAE:  {mae:.4f}")
# print(f"Test MAPE: {mape:.2f}%")
# print(f"Test R^2:  {r2:.4f}")

# %%
# def mape(y_true, y_pred):
#     return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error,mean_absolute_percentage_error


for i, name in enumerate(['H1', 'H2']):
    true = y_true_all[:, i]
    pred = y_pred_all[:, i]
    r2 = r2_score(true, pred)
    mae = mean_absolute_error(true, pred)
    rmse = np.sqrt(mean_squared_error(true, pred))
    mape_val = mean_absolute_percentage_error(true, pred)*100
    print(f"{name} → R²: {r2:.5f}, RMSE: {rmse:.5f},MAE: {mae:.5f}, MAPE: {mape_val:.2f}%")
# Out:
# H1 → R²: 0.97596, RMSE: 0.19673,MAE: 0.15681, MAPE: 2.87%
# H2 → R²: 0.90892, RMSE: 0.35291,MAE: 0.23452, MAPE: 3.85%

# %%
# Predict and Inverse-Transform y
# -------------------------------
Y_pred = y_pred_all.copy()

# Use the correct Y_test from THIS split as the true values for evaluation
Y_true = y_true_all.copy() # Now Y_true and Y_pred will have the same number of samples (219)

# -------------------------------
# Evaluate and Plot (assuming helper functions are defined elsewhere)
# -------------------------------
results = evaluate_predictions(Y_true,Y_pred) # Y_true and Y_pred have 219 samples

print("-------------------------------------------")
comparison_df = create_comparison_df(Y_true, Y_pred) # Use Y_true for consistency
print(comparison_df)

print("-------------------------------------------")

# Customized plot
fig = plot_predictions(Y_true, Y_pred, # Use Y_true
                      target_names=['H1', 'H2'],
                      figsize=(14, 6),
                      alpha=0.5,
                      color='blue')

# Basic boxplot
fig, stats = plot_error_analysis(Y_pred, Y_true) # Use Y_true

# Ensure Y_test is also a numpy array for plot_error_cdfs
fig = plot_error_cdfs(Y_true, Y_pred, target_names=['H1', 'H2']) # Use Y_true
# Out:
# H1 → R²: 0.97596, RMSE: 0.19673, MAE: 0.15681, MAPE: 2.87%
# H2 → R²: 0.90892, RMSE: 0.35291, MAE: 0.23452, MAPE: 3.85%
# -------------------------------------------
#      H1_actual   H1_pred  H2_actual   H2_pred
# 0     5.777544  5.983932   6.080493  6.059956
# 1     7.933983  7.947649   5.339190  5.493076
# 2     4.452408  4.491870   3.978493  3.929353
# 3     5.661653  5.909186   4.485403  4.628590
# 4     5.666003  5.577032   4.502955  4.489257
# ..         ...       ...        ...       ...
# 212   4.711536  4.717295   4.462227  4.583923
# 213   5.735140  5.698013   7.960858  7.892299
# 214   7.131289  7.376280   4.550109  4.367753
# 215   5.727813  5.970423   7.622150  6.840603
# 216   6.393566  6.575051   6.584186  6.785232
#
# [217 rows x 4 columns]
# -------------------------------------------
# 📊 Error Statistics:
#
# H1:
#   Mean Absolute Error: 0.1568
#   Median Absolute Error: 0.1383
#   Max Error: 0.8289
#   Standard Deviation: 0.1188
#
# H2:
#   Mean Absolute Error: 0.2345
#   Median Absolute Error: 0.1626
#   Max Error: 2.6908
#   Standard Deviation: 0.2637
# /tmp/ipython-input-2910689032.py:47: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([errors[:, i] for i in range(len(target_names))],

# %%
# H1 Plot
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.scatter(y_true_all[:, 0],y_pred_all[:, 0], alpha=0.6)
plt.plot([3, 8], [3, 8], 'r--')
plt.xlabel("True H1")
plt.ylabel("Predicted H1")
plt.title("H1 Prediction")
plt.grid(True)

# H2 Plot
plt.subplot(1, 2, 2)
plt.scatter(y_true_all[:, 1],y_pred_all[:, 1], alpha=0.6)
plt.plot([3, 8], [3, 8], 'r--')
plt.xlabel("True H2")
plt.ylabel("Predicted H2")
plt.title("H2 Prediction")
plt.grid(True)

plt.tight_layout()
plt.show()
